# %% [markdown]
# # Challenge 3

# %%
# import libraries here
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# #### Import the titanic file. Name your dataset `titanic`.

# %%
titanic = pd.read_csv('./titanic.csv',low_memory=False)
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500    U0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    U0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500    U0        S

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes

# %%
titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
#
# *Hint: Use Pandas `select_dtypes`*

# %%
num = titanic.select_dtypes(include=["float64", "int64"])
print(num.dtypes)
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Age            float64
# SibSp            int64
# Parch            int64
# Fare           float64
# dtype: object

# %%
obj = titanic.select_dtypes(include=["object"])
print(obj.dtypes)
# Out:
# Name        object
# Gender      object
# Ticket      object
# Cabin       object
# Embarked    object
# dtype: object

# %% [markdown]
# #### Set the plot style to `classic` and the figure size to `(12,6)`
#
# *Hint: To set the style you can use `matplotlib.pyplot` functions or seaborn*

# %%
plt.figure(figsize=(12,6))
plt.style.use("classic")

# %% [markdown]
# #### Use the appropriate visulalization to show the distribution of the column `Age`

# %%
plt.hist(titanic["Age"], bins=16)
plt.title("Age distribution in the Titanic")
# Out:
# Text(0.5, 1.0, 'Age distribution in the Titanic')

# %% [markdown]
# #### Use subplots to plot the distribution of the `Age` variable with bins equal to `10`, `20` and `50`.

# %%
fig, axes=plt.subplots(1,3)
axes[0].hist(titanic["Age"], color="y", bins=10)
axes[1].hist(titanic["Age"], bins=20, color="y")
axes[2].hist(titanic["Age"], bins=50, color="y");

# %% [markdown]
# #### Whether the bin size affects your plot? Why?

# %%
print("Sí. El eje OY es inversamente proporcional al binning. A mayor bin, la precisión del gráfico aumenta.")
# Out:
# Sí. El eje OY es inversamente proporcional al binning. A mayor bin, la precisión del gráfico aumenta.

# %% [markdown]
# #### Use seaborn to show the distribution of the column `Age`

# %%
sns.distplot(titanic["Age"], bins=16)
plt.title("Age distribution in the Titanic")
# Out:
# Text(0.5, 1.0, 'Age distribution in the Titanic')

# %% [markdown]
# #### Use the appropriate plot to visualize the column `Gender`. There are 2 ways of doing it. Do it both ways.
#
# *Hint: Use matplotlib and seaborn*

# %%
sns.countplot(x="Gender", data=titanic)

# %%
gender = titanic.groupby("Gender").agg({"Gender":"count"})
values = gender.Gender.values.tolist()
plt.pie(values, labels = ["female", "male"]);

# %% [markdown]
# #### Use the appropriate plot to visualize the column `Pclass`

# %%
sns.countplot(x="Pclass", data=titanic)

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. Choose the appropriate plot to show below.

# %%
titanic.boxplot(column="Age");

# %% [markdown]
# #### What does the previous plot tell you about the feature `Age`? Comment.

# %%
print("Aporta el rango de edad: la mínima es 0 y la máxima ronda los 80. Del 25 al 75% de la población se encuentra en un rango sobre los 20 y 38 años.")
# Out:
# Aporta el rango de edad: la mínima es 0 y la máxima ronda los 80. Del 25 al 75% de la población se encuentra en un rango sobre los 20 y 38 años.

# %% [markdown]
# #### Now in addition to the summary statistics, we also want to visualize the distribution of `Age`. Choose the appropriate plot to sow below.

# %%
sns.violinplot(x="Age", data=titanic)

# %% [markdown]
# #### What additional information in the previous plot provide you about the feature `Age`? Comment.

# %%
print("Se puede observar con el diagrama en forma de violín cómo la mediana está entre los 22 y los 40. Son raros los valores <0.")
# Out:
# Se puede observar con el diagrama en forma de violín cómo la mediana está entre los 22 y los 40. Son raros los valores <0.

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the appropriate plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
#
# *Hint: One of the ways involves using Seaborn*

# %%
sns.regplot("Age", "Fare", data=titanic)

# %%
sns.jointplot("Age", "Fare", data=titanic,  kind="reg")

# %% [markdown]
# #### Using Seaborn plot the correlation matrix of various features.
#
# *Hint: search how to use `heatmap`*

# %%
sns.heatmap(titanic.corr(), cmap="coolwarm")

# %% [markdown]
# #### According to the previous plot, what are the most correlated feature? Comment.

# %%
print("Se ve que en general las variables no están correlacionadas entre sí. Apenas Parch con SibSp.")
# Out:
# Se ve que en general las variables no están correlacionadas entre sí. Apenas Parch con SibSp.

# %% [markdown]
# #### Use the appropriate plot to display the summary statistics of the `Age` in function of the `Pclass`.
#
# *Hint: use boxplot to display summary statistics of `Age` in relation to each of the discrete values of `Pclass`*

# %%
titanic.boxplot("Age", "Pclass")

# %% [markdown]
# #### Use the appropriate plot to display the distributions of  `Age` in relation to  `Gender`.
#
# *Hint: use Facetgrid to display the distribution of `Age` for each categorical value of `Gender`*

# %%
titanic.boxplot("Age", "Gender")
