# %% [markdown]
# # Challenge 3

# %%
# import libraries here
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# #### Import the titanic file. Name your dataset `titanic`.

# %%
titanic = pd.read_csv('./titanic.csv',low_memory=False)
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500    U0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    U0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500    U0        S

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes

# %%
#your code here
titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
#
# *Hint: Use Pandas `select_dtypes`*

# %%
# your code here- numerical variable
titanic.select_dtypes(include= ('int64', 'float64'))
# Out:
#       PassengerId  Survived  Pclass        Age  SibSp  Parch      Fare
# 0               1       0.0       3  22.000000      1      0    7.2500
# 1               2       1.0       1  38.000000      1      0   71.2833
# 2               3       1.0       3  26.000000      0      0    7.9250
# 3               4       1.0       1  35.000000      1      0   53.1000
# 4               5       0.0       3  35.000000      0      0    8.0500
# ...           ...       ...     ...        ...    ...    ...       ...
# 1304         1305       NaN       3  29.513190      0      0    8.0500
# 1305         1306       NaN       1  39.000000      0      0  108.9000
# 1306         1307       NaN       3  38.500000      0      0    7.2500
# 1307         1308       NaN       3  29.513190      0      0    8.0500
# 1308         1309       NaN       3  25.315435      1      1   22.3583
#
# [1309 rows x 7 columns]

# %%
#your code here- categorical variable
titanic.select_dtypes(include=('int64','object'))
# Out:
#       PassengerId  Pclass                                               Name  \
# 0               1       3                            Braund, Mr. Owen Harris
# 1               2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2               3       3                             Heikkinen, Miss. Laina
# 3               4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4               5       3                           Allen, Mr. William Henry
# ...           ...     ...                                                ...
# 1304         1305       3                                 Spector, Mr. Woolf
# 1305         1306       1                       Oliva y Ocana, Dona. Fermina
# 1306         1307       3                       Saether, Mr. Simon Sivertsen
# 1307         1308       3                                Ware, Mr. Frederick
# 1308         1309       3                           Peter, Master. Michael J
#
# ...

# %% [markdown]
# #### Set the plot style to `classic` and the figure size to `(12,6)`
#
# *Hint: To set the style you can use `matplotlib.pyplot` functions or seaborn*

# %%
# your code here
plt.style.use('classic') # Works
# sns.set_style('classic') tira un error porque el style tiene que ser: white, dark, whitegrid, darkgrid, ticks
sns.set_style('dark')

# %% [markdown]
# #### Use the appropriate visulalization to show the distribution of the column `Age`

# %%
# your code here
plt.hist(titanic['Age'], bins = 50, color='steelblue');

# %% [markdown]
# #### Use subplots to plot the distribution of the `Age` variable with bins equal to `10`, `20` and `50`.

# %%
# your code here
plt.figure(figsize=(20,6))
binList = [10, 20, 50]
col = ["r", "b", "g"]
for ind, val in enumerate(binList):
    plt.subplot(1,3,ind+1)
    sns.distplot(titanic['Age'], bins=val, color=col[ind])
    plt.title(f"Bin number = {val}")

# %% [markdown]
# #### Whether the bin size affects your plot? Why?

# %%
#your comment here
'''
The more bins there are, the more specific is the information.
This is because when the bin number is small the data precission reduces in order to fit in a bin.
'''

# %% [markdown]
# #### Use seaborn to show the distribution of the column `Age`

# %%
# your code here
sns.distplot(titanic['Age'], color="b")

# %% [markdown]
# #### Use the appropriate plot to visualize the column `Gender`. There are 2 ways of doing it. Do it both ways.
#
# *Hint: Use matplotlib and seaborn*

# %%
# your code here- 1st way
titanic["Gender"].value_counts()
plt.pie(titanic['Gender'].value_counts(), colors=('steelblue', 'darkorange'), labels=('Male', 'Female'));

# %%
# your code here- 2nd way
sns.countplot("Gender",data=titanic, palette="Set2")

# %% [markdown]
# #### Use the appropriate plot to visualize the column `Pclass`

# %%
# your code here
sns.countplot("Pclass",data=titanic, palette="Set2")

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. Choose the appropriate plot to show below.

# %%
# your code here
sns.boxplot(titanic['Age'], color="teal")
sns.swarmplot(titanic['Age'], color="steelblue", size=2)

# %% [markdown]
# #### What does the previous plot tell you about the feature `Age`? Comment.

# %%
# your comment here
'''
The youngest person is 0 years old and the oldest is about 80
Most of the people are below 40
'''
# Out:
# '\nThe youngest person is 0 years old and the oldest is about 80\nMost of the people are below 40\n'

# %% [markdown]
# #### Now in addition to the summary statistics, we also want to visualize the distribution of `Age`. Choose the appropriate plot to sow below.

# %%
#your code here
fig, ax = plt.subplots()
ax.hist(titanic["Age"], color="steelblue")
plt.figtext(0.7, 0.6, titanic["Age"].describe().to_string());

# %% [markdown]
# #### What additional information in the previous plot provide you about the feature `Age`? Comment.

# %%
#your comment here
'''
There are 1309 people, with an average age of 29.9 years.
There is a deviation of 13.45 years from the average which means that the values are distributed from 0 to 80
25% of the people are below 22 years, 50% of the people are below 28 and 75% of people are below 37

'''
# Out:
# '\nThere are 1309 people, with an average age of 29.9 years.\nThere is a deviation of 13.45 years from the average which means that the values are distributed from 0 to 80\n25% of the people are below 22 years, 50% of the people are below 28 and 75% of people are below 37\n\n'

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the appropriate plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
#
# *Hint: One of the ways involves using Seaborn*

# %%
#your code-1st way
plt.figure(figsize=(10,10))
plt.scatter([e for e in range(len(titanic['Age']))], titanic['Age'], color="g" )
plt.scatter([e for e in range(len(titanic['Fare']))], titanic['Fare'], color="steelblue")
plt.xlabel("Num of people")
# Out:
# Text(0.5, 0, 'Num of people')

# %%
plt.figure(figsize=(10,10))
plt.scatter(titanic['Age'],titanic['Fare'], color="g" )
plt.xlabel("Age")
plt.ylabel("Fare")
# Out:
# Text(0, 0.5, 'Fare')

# %%
# your code-2nd way
sns.jointplot("Age", "Fare", data=titanic,  kind="reg")

# %% [markdown]
# #### Using Seaborn plot the correlation matrix of various features.
#
# *Hint: search how to use `heatmap`*

# %%
#your code here
sns.heatmap(titanic.corr(), vmin=-1) # DataFrame.corr() --> hace comparación pairwise entre elementos obviando los NA
                            # y devuelve un correlation matrix

# %% [markdown]
# #### According to the previous plot, what are the most correlated feature? Comment.

# %%
#your comment here
'''
The relation between Fare and Pclass is the most correlated feature
In the heatmap appears darker but this is because the higher the fare, the lower the class 1º Class >> 3ºClass

'''

# %% [markdown]
# #### Use the appropriate plot to display the summary statistics of the `Age` in function of the `Pclass`.
#
# *Hint: use boxplot to display summary statistics of `Age` in relation to each of the discrete values of `Pclass`*

# %%
#your code here
sns.boxplot(y = titanic['Age'],x= titanic["Pclass"], color="teal")

# %% [markdown]
# #### Use the appropriate plot to display the distributions of  `Age` in relation to  `Gender`.
#
# *Hint: use Facetgrid to display the distribution of `Age` for each categorical value of `Gender`*

# %%
#your code here

g = sns.FacetGrid(titanic, col="Gender", margin_titles=True)
g.map(plt.hist, "Age", color="steelblue")
