# %% [markdown]
# # Challenge 3

# %%
# import libraries here
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
'''
import numpy as np

# %matplotlib inline
'''
# Out:
# '\nimport numpy as np\n\n%matplotlib inline\n'

# %% [markdown]
# #### Import the titanic file. Name your dataset `titanic`.

# %%
titanic = pd.read_csv('./titanic.csv',low_memory=False)
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500    U0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    U0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500    U0        S

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes

# %%
#your code here
print(titanic.dtypes)
print(titanic.shape)
print(titanic.columns)
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object
# (1309, 12)
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Gender', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
#
# *Hint: Use Pandas `select_dtypes`*

# %%
# your code here- numerical variable
titanic.select_dtypes(include=['int64','float64']).columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare'], dtype='object')

# %%
#your code here- categorical variable
titanic.select_dtypes(include='object').columns
# Out:
# Index(['Name', 'Gender', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %% [markdown]
# #### Set the plot style to `classic` and the figure size to `(12,6)`
#
# *Hint: To set the style you can use `matplotlib.pyplot` functions or seaborn*

# %%
# your code here
import matplotlib.style
plt.style.use('classic')
plt.figure(figsize=(12,6))

# %% [markdown]
# #### Use the appropriate visulalization to show the distribution of the column `Age`

# %%
# your code here
plt.hist(titanic.Age)
# Out:
# (array([ 72.,  78., 326., 347., 220., 136.,  75.,  42.,  10.,   3.]),
#  array([ 0.17 ,  8.153, 16.136, 24.119, 32.102, 40.085, 48.068, 56.051,
#         64.034, 72.017, 80.   ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# #### Use subplots to plot the distribution of the `Age` variable with bins equal to `10`, `20` and `50`.

# %%
# your code here
for e,i in [(1,10),(2,20),(3,50)]:
    plt.subplot(3,1,e)
    plt.hist(titanic.Age, bins=i)

# %% [markdown]
# #### Whether the bin size affects your plot? Why?

# %%
#your comment here
print('Más bins implica mayor distribución de los datos permitiendonos observar más los cambios')
# Out:
# Más bins implica mayor distribución de los datos permitiendonos observar más los cambios

# %% [markdown]
# #### Use seaborn to show the distribution of the column `Age`

# %%
# your code here
sns.distplot(titanic.Age)

# %% [markdown]
# #### Use the appropriate plot to visualize the column `Gender`. There are 2 ways of doing it. Do it both ways.
#
# *Hint: Use matplotlib and seaborn*

# %%
# your code here- 1st way
genero = {}
genero['male']= titanic.where(titanic['Gender']=='male')['Gender'].count()
genero['female']=titanic.shape[0]-genero['male']
print(genero)
plt.pie(genero.values(), labels = genero.keys(), autopct="%.1f");
# Out:
# {'male': 843, 'female': 466}

# %%
# your code here- 2nd way
sns.countplot('Gender', data=titanic);

# %% [markdown]
# #### Use the appropriate plot to visualize the column `Pclass`

# %%
# your code here
sns.countplot('Pclass', data=titanic);

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. Choose the appropriate plot to show below.

# %%
# your code here
print(titanic.Age.describe())
plt.figure(figsize =(10,3))
sns.boxplot('Age',data=titanic)
# Out:
# count    1309.000000
# mean       29.879186
# std        13.448335
# min         0.170000
# 25%        22.000000
# 50%        28.500000
# 75%        37.000000
# max        80.000000
# Name: Age, dtype: float64

# %% [markdown]
# #### What does the previous plot tell you about the feature `Age`? Comment.

# %%
# your comment here
print('La mayoria de pasajeros tenian entre 22 y 37 años aproximadamente. La edad maxima son los 80 y la minima cerca de 0.')
# Out:
# La mayoria de pasajeros tenian entre 22 y 37 años aproximadamente. La edad maxima son los 80 y la minima cerca de 0.

# %% [markdown]
# #### Now in addition to the summary statistics, we also want to visualize the distribution of `Age`. Choose the appropriate plot to sow below.

# %%
#your code here
sns.distplot(titanic.Age)

# %% [markdown]
# #### What additional information in the previous plot provide you about the feature `Age`? Comment.

# %%
#your comment here
print('Volvemos a observar que la mayoria de gente tenia entre 20 y 40 años. Poca gente superaba los 60 años y había algun recion nacido o niño muy pequeño.')
# Out:
# Volvemos a observar que la mayoria de gente tenia entre 20 y 40 años. Poca gente superaba los 60 años y había algun recion nacido o niño muy pequeño.

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the appropriate plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
#
# *Hint: One of the ways involves using Seaborn*

# %%
#your code-1st way
plt.plot(titanic['Fare'],titanic['Age'])

# %%
# your code-2nd way
sns.jointplot('Fare','Age', data=titanic, kind='reg')

# %% [markdown]
# #### Using Seaborn plot the correlation matrix of various features.
#
# *Hint: search how to use `heatmap`*

# %%
#your code here
sns.heatmap(titanic.corr())

# %% [markdown]
# #### According to the previous plot, what are the most correlated feature? Comment.

# %%
#your comment here
print('The most correlated ones are Parch and SibSp')
# Out:
# The most correlated ones are Parch and SibSp

# %% [markdown]
# #### Use the appropriate plot to display the summary statistics of the `Age` in function of the `Pclass`.
#
# *Hint: use boxplot to display summary statistics of `Age` in relation to each of the discrete values of `Pclass`*

# %%
#your code here
plt.figure()
sns.boxplot('Pclass','Age',data=titanic)

# %% [markdown]
# #### Use the appropriate plot to display the distributions of  `Age` in relation to  `Gender`.
#
# *Hint: use Facetgrid to display the distribution of `Age` for each categorical value of `Gender`*

# %%
#your code here
g = sns.FacetGrid(titanic, col="Gender")
g.map(plt.hist, "Age")
