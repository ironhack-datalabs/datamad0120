# %% [markdown]
# # Challenge 3

# %%
# import libraries here
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# #### Import the titanic file. Name your dataset `titanic`.

# %%
titanic = pd.read_csv('./titanic.csv',low_memory=False)
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500    U0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    U0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500    U0        S

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes

# %%
# VER TIPO DE DATOS POR COLUMNA

titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
#
# *Hint: Use Pandas `select_dtypes`*

# %%
# SELECCIONAR VARIABLES NUMERICAS

titanic.select_dtypes(exclude=object).head()
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare
# 0            1       0.0       3  22.0      1      0   7.2500
# 1            2       1.0       1  38.0      1      0  71.2833
# 2            3       1.0       3  26.0      0      0   7.9250
# 3            4       1.0       1  35.0      1      0  53.1000
# 4            5       0.0       3  35.0      0      0   8.0500

# %%
# SELECCIONAR VARIABLES CATEGORICAS

titanic.select_dtypes(object).head()
# Out:
#                                                 Name  Gender  \
# 0                            Braund, Mr. Owen Harris    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                             Heikkinen, Miss. Laina  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                           Allen, Mr. William Henry    male
#
#              Ticket Cabin Embarked
# 0         A/5 21171    U0        S
# 1          PC 17599   C85        C
# 2  STON/O2. 3101282    U0        S
# 3            113803  C123        S
# 4            373450    U0        S

# %% [markdown]
# #### Set the plot style to `classic` and the figure size to `(12,6)`
#
# *Hint: To set the style you can use `matplotlib.pyplot` functions or seaborn*

# %%
# ESTABLECES ESTILO Y TAMAÑO

plt.style.use('classic')
plt.rcParams['figure.figsize'] = (12, 6)

# %% [markdown]
# #### Use the appropriate visulalization to show the distribution of the column `Age`

# %%
# DISTRIBUCION VARIABLES DE COLUMNADISTRIBUCION VARIABLES DE COLUMNA

titanic['Age'].hist();

# %% [markdown]
# #### Use subplots to plot the distribution of the `Age` variable with bins equal to `10`, `20` and `50`.

# %%
# BINS: controlar el rango de distribución

plt.subplot(1,3,1)
titanic['Age'].hist(bins = 10)

plt.subplot(1,3,2)
titanic['Age'].hist(bins = 20)

plt.subplot(1,3,3)
titanic['Age'].hist(bins = 50);

# %% [markdown]
# #### Whether the bin size affects your plot? Why?

# %%
# Cómo afectan las bins?

'''Cuanto mayor es el bin, más detalle conseguimos. En el primer subplot los datos se agrupan 
y se pierde información.'''
# Out:
# 'Cuanto mayor es el bin, más detalle conseguimos. En el primer subplot los datos se agrupan \ny se pierde información.'

# %% [markdown]
# #### Use seaborn to show the distribution of the column `Age`

# %%
# SEABORN - DISTRIBUCION VARIABLES DE COLUMNA

sns.distplot(titanic['Age']);
# Out:
# /usr/lib/python3/dist-packages/seaborn/distributions.py:214: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   color=hist_color, **hist_kws)

# %% [markdown]
# #### Use the appropriate plot to visualize the column `Gender`. There are 2 ways of doing it. Do it both ways.
#
# *Hint: Use matplotlib and seaborn*

# %%
# TIPO 1 SEABORN: comparar una variable dicotómica con dos barras

sns.countplot(x='Gender',data=titanic);
# Out:
# /usr/lib/python3/dist-packages/seaborn/categorical.py:1460: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   stat_data = remove_na(group_data)

# %%
# TIPO 2 MATPLOTLIB: comparar una variable dicotómica con dos barras

titanic['Gender'].value_counts().plot(kind='bar');

# %% [markdown]
# #### Use the appropriate plot to visualize the column `Pclass`

# %%
# GRAFICO DE BARRAS: representar columna con poca distribución

titanic['Pclass'].value_counts().plot(kind='bar');

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. Choose the appropriate plot to show below.

# %%
# BOXPLOT: da información sobre la distribución, la mediana y los valores máximos y mínimos.

titanic.boxplot(column='Age');

# %% [markdown]
# #### What does the previous plot tell you about the feature `Age`? Comment.

# %%
# Explicación gráfico anterior.

'''La mayoría de la gente está entre 22 y 37 años.'''
# Out:
# 'La mayoría de la gente está entre 22 y 37 años.'

# %% [markdown]
# #### Now in addition to the summary statistics, we also want to visualize the distribution of `Age`. Choose the appropriate plot to sow below.

# %%
#your code here

sns.violinplot(x="Age", data=titanic);
# Out:
# /usr/lib/python3/dist-packages/seaborn/categorical.py:598: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   kde_data = remove_na(group_data)
# /usr/lib/python3/dist-packages/seaborn/categorical.py:826: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   violin_data = remove_na(group_data)

# %% [markdown]
# #### What additional information in the previous plot provide you about the feature `Age`? Comment.

# %%
#your comment here

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the appropriate plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
#
# *Hint: One of the ways involves using Seaborn*

# %%
# BUSCAR RELACION ENTRE DOS VARIABLES

sns.jointplot(x='Age', y='Fare', data=titanic);
# Out:
# /usr/lib/python3/dist-packages/seaborn/distributions.py:214: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   color=hist_color, **hist_kws)

# %%
# your code-2nd way

# %% [markdown]
# #### Using Seaborn plot the correlation matrix of various features.
#
# *Hint: search how to use `heatmap`*

# %%
# Matriz que correlaciona todas las variables entre sí.

sns.heatmap(titanic.corr());

# %% [markdown]
# #### According to the previous plot, what are the most correlated feature? Comment.

# %%
# Explicación gráfico anterior.

'''Cuanto más cercano a 1, más correlación. Las celdas más claras tienen mayor correlación. 
SibSp & Parch (sibilingsParents & ParentsChildren). También correlaciona de forma negativa la clase y la tarifa.'''
# Out:
# 'Cuanto más cercano a 1, más correlación. Las celdas más claras tienen mayor correlación. \nSibSp & Parch (sibilingsParents & ParentsChildren). También correlaciona de forma negativa la clase y la tarifa.'

# %% [markdown]
# #### Use the appropriate plot to display the summary statistics of the `Age` in function of the `Pclass`.
#
# *Hint: use boxplot to display summary statistics of `Age` in relation to each of the discrete values of `Pclass`*

# %%
#your code here

sns.boxplot(x = 'Pclass', y = 'Age', data = titanic);
# Out:
# /usr/lib/python3/dist-packages/seaborn/categorical.py:462: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   box_data = remove_na(group_data)
# /usr/lib/python3/dist-packages/seaborn/categorical.py:462: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   box_data = remove_na(group_data)
# /usr/lib/python3/dist-packages/seaborn/categorical.py:462: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   box_data = remove_na(group_data)

# %% [markdown]
# #### Use the appropriate plot to display the distributions of  `Age` in relation to  `Gender`.
#
# *Hint: use Facetgrid to display the distribution of `Age` for each categorical value of `Gender`*

# %%
#your code here

sns.boxplot(x = 'Gender', y = 'Age', data = titanic);
# Out:
# /usr/lib/python3/dist-packages/seaborn/categorical.py:462: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   box_data = remove_na(group_data)
# /usr/lib/python3/dist-packages/seaborn/categorical.py:462: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   box_data = remove_na(group_data)
