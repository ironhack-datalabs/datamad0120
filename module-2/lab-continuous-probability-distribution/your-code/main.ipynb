# %% [markdown]
# # Before your start:
#
#     Read the README.md file
#     Comment as much as you can and use the resources (README.md file)
#     Happy learning!

# %% [markdown]
# In this exercise, we  will generate random numbers from the continuous disributions we learned in the lesson. There are two ways to generate random numbers:
#
# 1. Using the numpy library
# 1. using the Scipy library
#
# Use either or both of the lbraries in this exercise.

# %% [markdown]
# # Imports

# %%
from scipy.stats import uniform
from scipy import stats
from scipy.stats import kurtosis
import numpy as np
import pandas as pd

import random
import matplotlib.pyplot as plt

# %% [markdown]
# ## Uniform Distribution
#
# To generate uniform random numbers between any two given values using scipy, we can either use the following code or the code that we have
# discussed in class:

# %%
x = uniform.rvs(size=10)
a = 2
b = 3
randoms  = a + (b-a)*x
print(randoms)
# Out:
# [2.86252104 2.02557222 2.95607387 2.60990632 2.90185409 2.45620593
#  2.10679632 2.15793339 2.74095802 2.14488577]

# %% [markdown]
# **Your task:**
#
# 1. Based on the code above, write a function that generates uniformly distributed random numbers. There are several requirements for your function:
#     * It should accept 3 parameters:
#         * `bottom` - the lower boundary of the generated numbers
#         * `ceiling` - the upper boundary of the generated numbers
#         * `count` - how many numbers to generate
#     * It should return an array of uniformly distributed random numbers
#
# 1. Call your function with 2 sets of params below:
#     * bottom=10, ceiling=15, count=100
#     * bottom=10, ceiling=60, count=1,000
#
# 1. Plot the uniform distributions generated above using histograms, where x axis is the value and y axis is the count. Let the histogram's number of bins be 10.
#
# Your output should look like below:
#
# ![uniform distribution](ud.png)

# %%
#Función

def uniform_dist(bottom=0,ceiling=0, count=0):
    return [random.uniform(bottom,ceiling) for i in range(count)]

# %%
#Comprobaciones

print(len(uniform_dist(bottom=10, ceiling=15, count=100)))

uniform_dist(bottom=10, ceiling=60, count=1000)[:5]
# Out:
# 100
# [30.667266668578115,
#  17.673462202954962,
#  37.70643224087,
#  33.26296900131506,
#  50.09281476137899]

# %%
#Representación Gráfica

fig, axs = plt.subplots(1, 2, sharey=True, tight_layout=True)

x1 = uniform_dist(bottom=10, ceiling=15, count=100)
x2 = uniform_dist(bottom=10, ceiling=60, count=1000)

axs[0].hist(x1, bins=10)
axs[1].hist(x2, bins=10)

plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# How are the two distributions different?

# %% [markdown]
# Una de las principales características de las distribuciones uniformes corresponde al caso de que una variable aleatoria sólo puede tomar valores comprendidos entre dos extremos "bottom" y "ceiling".
#
# Así en la primera gráfica, la probabilidad se distribuye entre el rango asignado de 10 y 15.
#
# Por otro lado, en la segunda gráfica se distribuye entre 10 y 60. Además, por el mayor número de muestras aportado, las probabilidades aumentan considerablemente para cada punto de dicho rango.

# %% [markdown]
# ## Normal Distribution
#
# 1. In the same way in the Uniform Distribution challenge, write a function that generates normally distributed random numbers.
# 1. Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 1
# 1. Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 50
# 2. Plot the distributions of the data generated.
#
# Expected output:
#
# ![normal distribution](nd.png)

# %%
#  Función

def normal_dist(average,std,count):
    return [np.random.normal(average,std) for i in range(count)]

# %%
#Comprobaciones

print(len(normal_dist(10,1,1000)))

normal_dist(10,1,1000)[:5]
# Out:
# 1000
# [9.441568092524832,
#  9.77834786794337,
#  9.861770417808133,
#  11.509083320478211,
#  9.114710582520754]

# %%
#Representación Gráfica

fig, axs = plt.subplots(1, 2, sharey=True, tight_layout=True)

x1 = normal_dist(10,1,1000)
x2 = normal_dist(10,50,1000)

axs[0].hist(x1, bins=50)
axs[1].hist(x2, bins=50)

plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# How are the two distributions different?

# %% [markdown]
# La media de ambas gráficas se sitúan en 10, pero el gran número de muestras y desviación típica de la segunda gráfica provocan que dicha media quede "desvirtuada" al dibujarse.
#
# Continuando por esta cuestión, la amplia desviación típica de la segunda gráfica provoca una mayor dispersión de los datos en torno a la media respecto a la primera gráfica.
#
# Por otro lado, la segunda gráfica presenta una mayor precisión en su representación al disponer de mayor número de muestras.

# %% [markdown]
# ## Normal Distribution of Real Data
#
# In this challenge we are going to take a look the real data. We will use vehicles.csv file for this exercise

# %% [markdown]
# First import vehicles.csv.
# Then plot the histograms for the following variables:

# %%
df = pd.read_csv("vehicles.csv") 

print(df.shape)

df.head(3)
# Out:
# (35952, 15)
#          Make                Model  Year  Engine Displacement  Cylinders  \
# 0  AM General    DJ Po Vehicle 2WD  1984                  2.5        4.0
# 1  AM General     FJ8c Post Office  1984                  4.2        6.0
# 2  AM General  Post Office DJ5 2WD  1985                  2.5        4.0
#
#       Transmission        Drivetrain                Vehicle Class Fuel Type  \
# 0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD   Regular
# 1  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD   Regular
# 2  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD   Regular
#
#    Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# 0          19.388824        18           17            17
# 1          25.354615        13           13            13
# 2          20.600625        16           17            16
#
#    CO2 Emission Grams/Mile  Fuel Cost/Year
# 0               522.764706            1950
# ...

# %% [markdown]
# 1. Fuel Barrels/Year

# %%
# your code here

plt.hist(df["Fuel Barrels/Year"], bins=30)

plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# 2. CO2 Emission Grams/Mile

# %%
# your code here

plt.hist(df["CO2 Emission Grams/Mile"],bins=30)

plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# 3. Combined MPG

# %%
# your code here

plt.hist(df["Combined MPG"],bins=30)

plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# Which one(s) of the variables are nearly normally distributed? How do you know?

# %%
# your answer here

p = stats.normaltest(df["Fuel Barrels/Year"])
p
# Out:
# NormaltestResult(statistic=3216.559790182245, pvalue=0.0)

# %%
p = stats.normaltest(df["CO2 Emission Grams/Mile"])
p
# Out:
# NormaltestResult(statistic=3608.604030545311, pvalue=0.0)

# %%
p = stats.normaltest(df["Combined MPG"])
p
# Out:
# NormaltestResult(statistic=6994.459897617527, pvalue=0.0)

# %% [markdown]
# H0: g = distribución normal
#
# A pesar de la enorme cantidad de muestras que presenta cada columna del dataset, las distribuciones de dichas columnas no se han aproximado demasiado a una Distribución normal según los tests realizados...
#
# Por otro lado, a ojo, mi principal elección como distribución normal sería la primera gráfica ("Fuel Barrels/Year") basándome en la forma de la campana y la extensión de las colas.
#
# A continuación realizo un análisis de curtosis para analizar dicha forma.

# %%
kurtosis(df["Fuel Barrels/Year"])
# Out:
# 1.467913801930207

# %% [markdown]
# La curtosis es inferior a 3, por tanto la "forma" de la distribución está alejada de una normal.

# %% [markdown]
# ## Exponential Distribution

# %% [markdown]
# 1. Using `numpy.random.exponential`, create a function that returns a list of numbers exponentially distributed with the mean of 10.
#
# 1. Use the function to generate two number sequences with the size of 10 and 100.
#
# 1. Plot the distributions as histograms with the nubmer of bins as 100.
#
# Your output should look like below:
#
# ![exponential distribution](ed.png)

# %%
# your code here

def exp_dist(average,count):
    return [np.random.exponential(1/average,size=count)]

# %%
#Comprobaciones

print(len(exp_dist(10,10)))

exp_dist(10,10)[:5]
# Out:
# 1
# [array([0.04944263, 0.07168956, 0.06309722, 0.00712784, 0.02961456,
#         0.25947066, 0.03455102, 0.00154319, 0.05434646, 0.10601871])]

# %%
#Representación Gráfica

fig, axs = plt.subplots(1, 2, sharey=True)

x1 = exp_dist(10,10)
x2 = exp_dist(10,100)

axs[0].hist(x1,bins=100)
axs[1].hist(x2, bins=100)

plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# How are the two distributions different?

# %%
# your answer here

# %% [markdown]
# ## Exponential Distribution of Real Data
#
# Suppose that the amount of time one spends in a bank is exponentially distributed with mean as 10 minutes (i.e. λ = 1/10). What is the probability that a customer will spend less than fifteen minutes in the bank?
#
# Write a code in python to solve this problem

# %%
# your answer here
# Hint: This is same as saying P(x<15)

# %% [markdown]
# What is the probability that the customer will spend more than 15 minutes

# %%
# your answer here
