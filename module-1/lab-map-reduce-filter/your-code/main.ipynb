# %% [markdown]
# # Before your start:
# - Read the README.md file
# - Comment as much as you can and use the resources in the README.md file
# - Happy learning!

# %%
# import reduce from functools, numpy and pandas
import numpy as np
import pandas as pd
from functools import reduce

# %% [markdown]
# # Challenge 1 - Mapping
#
# #### We will use the map function to clean up a words in a book.
#
# In the following cell, we will read a text file containing the book The Prophet by Khalil Gibran.

# %%
# Run this code:

location = '../58585-0.txt'
with open(location, 'r', encoding="utf8") as f:
    prophet = f.read().split(' ')

# %% [markdown]
# #### Let's remove the first 568 words since they contain information about the book but are not part of the book itself.
#
# Do this by removing from `prophet` elements 0 through 567 of the list (you can also do this by keeping elements 568 through the last element).

# %%
# Your code here:
filtro = lambda x: prophet.index(x) > 567
filtered = list(filter(filtro, prophet))
print(filtered)
# Out:
# ['PROPHET\n\n|Almustafa,', 'the{7}', 'chosen', 'the\nbeloved,', 'who', 'was', 'dawn', 'unto', 'own\nday,', 'had', 'waited', 'twelve', 'years', 'city\nof', 'Orphalese', 'ship', 'that', 'was', 'to\nreturn', 'bear', 'him', 'back', 'isle', 'of\nhis', 'birth.\n\nAnd', 'twelfth', 'year,', 'on', 'seventh\nday', 'Ielool,', 'month', 'reaping,', 'he\nclimbed', 'hill', 'without', 'city', 'walls\nand', 'looked', 'seaward;', 'beheld', 'his\nship', 'coming', 'mist.\n\nThen', 'gates', 'heart', 'flung\nopen,', 'joy', 'flew', 'far', 'over', 'sea.\nAnd', 'closed', 'eyes', 'prayed', 'the\nsilences', 'soul.\n\n*****\n\nBut', 'as', 'descended', 'hill,', 'sadness\ncame', 'upon', 'him,', 'thought', 'his\nheart:\n\nHow', 'shall', 'I', 'go', 'peace', 'without\nsorrow?', 'Nay,', 'without', 'wound', 'the\nspirit', 'shall', 'I', 'leave', 'city.', '{8}Long\nwere', 'days', 'pain', 'I', 'have', 'spent\nwithin', 'its', 'walls,', 'long', 'the\nnights', 'aloneness;', 'who', 'can', 'depart\nfrom', 'pain', 'aloneness', 'without\nregret?\n\nToo', 'many', 'fragments', 'spirit', 'have', 'I\nscattered', 'these', 'streets,', 'too', 'many\nare', 'children', 'my', 'longing', 'that', 'walk\nnaked', 'among', 'these', 'hills,', 'I', 'cannot\nwithdraw', 'them', 'without', 'burden', 'and\nan', 'ache.\n\nIt', 'garment', 'I', 'cast', 'off', 'this\nday,', 'skin', 'that', 'I', 'tear', 'my', 'own\nhands.\n\nNor', 'thought', 'I', 'leave', 'behind', 'me,\nbut', 'heart', 'made', 'sweet', 'hunger', 'and\nwith', 'thirst.\n\n*****\n\nYet', 'I', 'cannot', 'tarry', 'longer.\n\nThe', 'sea', 'that', 'calls', 'things', 'unto', 'her\ncalls', 'me,', 'I', 'must', 'embark.\n\nFor', 'stay,', 'though', 'hours', 'burn', 'in\nthe', 'night,', 'freeze', 'crystallize\nand', 'be', 'bound', 'mould.\n\nFain', 'would', 'I', 'take', 'me', 'that', 'is\nhere.', 'But', 'how', 'shall', 'I?\n\nA', 'voice', 'cannot', 'carry', 'tongue', 'and\n{9}the', 'lips', 'that', 'gave', 'wings.', 'Alone\nmust', 'seek', 'ether.\n\nAnd', 'alone', 'without', 'nest', 'shall', 'the\neagle', 'fly', 'across', 'sun.\n\n*****\n\nNow', 'when', 'reached', 'foot', 'the\nhill,', 'turned', 'again', 'towards', 'sea,\nand', 'saw', 'ship', 'approaching', 'the\nharbour,', 'upon', 'her', 'prow', 'mariners,\nthe', 'men', 'own', 'land.\n\nAnd', 'soul', 'cried', 'out', 'them,', 'he\nsaid:\n\nSons', 'my', 'ancient', 'mother,', 'riders', 'of\nthe', 'tides,\n\nHow', 'often', 'have', 'sailed', 'my', 'dreams.\nAnd', 'now', 'come', 'my', 'awakening,', 'which\nis', 'my', 'deeper', 'dream.\n\nReady', 'am', 'I', 'go,', 'my', 'eagerness', 'with\nsails', 'full', 'awaits', 'wind.\n\nOnly', 'another', 'breath', 'will', 'I', 'breathe', 'in\nthis', 'still', 'air,', 'only', 'another', 'loving', 'look\ncast', 'backward,\n\nAnd', 'then', 'I', 'shall', 'stand', 'among', 'you,', 'a\nseafarer', 'among', 'seafarers.', '{10}And', 'you,\nvast', 'sea,', 'sleepless', 'mother,\n\nWho', 'alone', 'peace', 'freedom', 'the\nriver', 'stream,\n\nOnly', 'another', 'winding', 'will', 'stream\nmake,', 'only', 'another', 'murmur', 'glade,\n\nAnd', 'then', 'shall', 'I', 'come', 'you,', 'a\nboundless', 'drop', 'boundless', 'ocean.\n\n*****\n\nAnd', 'as', 'walked', 'saw', 'afar', 'men\nand', 'women', 'leaving', 'their', 'fields', 'their\nvineyards', 'hastening', 'towards', 'city\ngates.\n\nAnd', 'heard', 'their', 'voices', 'calling', 'his\nname,', 'shouting', 'field', 'field\ntelling', 'one', 'another', 'coming', 'his\nship.\n\nAnd', 'said', 'himself:\n\nShall', 'day', 'parting', 'be', 'day', 'of\ngathering?\n\nAnd', 'shall', 'be', 'said', 'that', 'my', 'eve', 'was', 'in\ntruth', 'my', 'dawn?\n\nAnd', 'what', 'shall', 'I', 'unto', 'him', 'who', 'has\nleft', 'plough', 'midfurrow,', 'to\nhim', 'who', 'has', 'stopped', 'wheel', 'his\nwinepress?', '{11}Shall', 'my', 'heart', 'become', 'a\ntree', 'heavy-laden', 'fruit', 'that', 'I', 'may\ngather', 'unto', 'them?\n\nAnd', 'shall', 'my', 'desires', 'flow', 'like', 'a\nfountain', 'that', 'I', 'fill', 'their', 'cups?\n\nAm', 'I', 'harp', 'that ...

# %% [markdown]
# If you look through the words, you will find that many words have a reference attached to them. For example, let's look at words 1 through 10.

# %%
# Your code here:
print(list(filtered[e] for e in range(10)))
# Out:
# ['PROPHET\n\n|Almustafa,', 'the{7}', 'chosen', 'the\nbeloved,', 'who', 'was', 'dawn', 'unto', 'own\nday,', 'had']

# %% [markdown]
# #### The next step is to create a function that will remove references.
#
# We will do this by splitting the string on the `{` character and keeping only the part before this character. Write your function below.

# %%
def reference(x):
    '''
    Input: A string
    Output: The string with references removed
    
    Example:
    Input: 'the{7}'
    Output: 'the'
    '''
    if '{' in x:
        a = x.split('{')[0]
        b = x.split('}')[1]
        
        if a != '' and b != '':
            c = (a, b)
            return str(c)
        elif a != '' and b == '':
            return str(a)
        elif a == '' and b != '':
            return str(b)
        
        return a, b
    else:
        return x

# %% [markdown]
# Now that we have our function, use the `map()` function to apply this function to our book, The Prophet. Return the resulting list to a new list called `prophet_reference`

# %%
# Your code here:
prophet_reference = list(map(reference, filtered))
print(prophet_reference)
# Out:
# ['PROPHET\n\n|Almustafa,', 'the', 'chosen', 'the\nbeloved,', 'who', 'was', 'dawn', 'unto', 'own\nday,', 'had', 'waited', 'twelve', 'years', 'city\nof', 'Orphalese', 'ship', 'that', 'was', 'to\nreturn', 'bear', 'him', 'back', 'isle', 'of\nhis', 'birth.\n\nAnd', 'twelfth', 'year,', 'on', 'seventh\nday', 'Ielool,', 'month', 'reaping,', 'he\nclimbed', 'hill', 'without', 'city', 'walls\nand', 'looked', 'seaward;', 'beheld', 'his\nship', 'coming', 'mist.\n\nThen', 'gates', 'heart', 'flung\nopen,', 'joy', 'flew', 'far', 'over', 'sea.\nAnd', 'closed', 'eyes', 'prayed', 'the\nsilences', 'soul.\n\n*****\n\nBut', 'as', 'descended', 'hill,', 'sadness\ncame', 'upon', 'him,', 'thought', 'his\nheart:\n\nHow', 'shall', 'I', 'go', 'peace', 'without\nsorrow?', 'Nay,', 'without', 'wound', 'the\nspirit', 'shall', 'I', 'leave', 'city.', 'Long\nwere', 'days', 'pain', 'I', 'have', 'spent\nwithin', 'its', 'walls,', 'long', 'the\nnights', 'aloneness;', 'who', 'can', 'depart\nfrom', 'pain', 'aloneness', 'without\nregret?\n\nToo', 'many', 'fragments', 'spirit', 'have', 'I\nscattered', 'these', 'streets,', 'too', 'many\nare', 'children', 'my', 'longing', 'that', 'walk\nnaked', 'among', 'these', 'hills,', 'I', 'cannot\nwithdraw', 'them', 'without', 'burden', 'and\nan', 'ache.\n\nIt', 'garment', 'I', 'cast', 'off', 'this\nday,', 'skin', 'that', 'I', 'tear', 'my', 'own\nhands.\n\nNor', 'thought', 'I', 'leave', 'behind', 'me,\nbut', 'heart', 'made', 'sweet', 'hunger', 'and\nwith', 'thirst.\n\n*****\n\nYet', 'I', 'cannot', 'tarry', 'longer.\n\nThe', 'sea', 'that', 'calls', 'things', 'unto', 'her\ncalls', 'me,', 'I', 'must', 'embark.\n\nFor', 'stay,', 'though', 'hours', 'burn', 'in\nthe', 'night,', 'freeze', 'crystallize\nand', 'be', 'bound', 'mould.\n\nFain', 'would', 'I', 'take', 'me', 'that', 'is\nhere.', 'But', 'how', 'shall', 'I?\n\nA', 'voice', 'cannot', 'carry', 'tongue', "('and\\n', 'the')", 'lips', 'that', 'gave', 'wings.', 'Alone\nmust', 'seek', 'ether.\n\nAnd', 'alone', 'without', 'nest', 'shall', 'the\neagle', 'fly', 'across', 'sun.\n\n*****\n\nNow', 'when', 'reached', 'foot', 'the\nhill,', 'turned', 'again', 'towards', 'sea,\nand', 'saw', 'ship', 'approaching', 'the\nharbour,', 'upon', 'her', 'prow', 'mariners,\nthe', 'men', 'own', 'land.\n\nAnd', 'soul', 'cried', 'out', 'them,', 'he\nsaid:\n\nSons', 'my', 'ancient', 'mother,', 'riders', 'of\nthe', 'tides,\n\nHow', 'often', 'have', 'sailed', 'my', 'dreams.\nAnd', 'now', 'come', 'my', 'awakening,', 'which\nis', 'my', 'deeper', 'dream.\n\nReady', 'am', 'I', 'go,', 'my', 'eagerness', 'with\nsails', 'full', 'awaits', 'wind.\n\nOnly', 'another', 'breath', 'will', 'I', 'breathe', 'in\nthis', 'still', 'air,', 'only', 'another', 'loving', 'look\ncast', 'backward,\n\nAnd', 'then', 'I', 'shall', 'stand', 'among', 'you,', 'a\nseafarer', 'among', 'seafarers.', 'And', 'you,\nvast', 'sea,', 'sleepless', 'mother,\n\nWho', 'alone', 'peace', 'freedom', 'the\nriver', 'stream,\n\nOnly', 'another', 'winding', 'will', 'stream\nmake,', 'only', 'another', 'murmur', 'glade,\n\nAnd', 'then', 'shall', 'I', 'come', 'you,', 'a\nboundless', 'drop', 'boundless', 'ocean.\n\n*****\n\nAnd', 'as', 'walked', 'saw', 'afar', 'men\nand', 'women', 'leaving', 'their', 'fields', 'their\nvineyards', 'hastening', 'towards', 'city\ngates.\n\nAnd', 'heard', 'their', 'voices', 'calling', 'his\nname,', 'shouting', 'field', 'field\ntelling', 'one', 'another', 'coming', 'his\nship.\n\nAnd', 'said', 'himself:\n\nShall', 'day', 'parting', 'be', 'day', 'of\ngathering?\n\nAnd', 'shall', 'be', 'said', 'that', 'my', 'eve', 'was', 'in\ntruth', 'my', 'dawn?\n\nAnd', 'what', 'shall', 'I', 'unto', 'him', 'who', 'has\nleft', 'plough', 'midfurrow,', 'to\nhim', 'who', 'has', 'stopped', 'wheel', 'his\nwinepress?', 'Shall', 'my', 'heart', 'become', 'a\ntree', 'heavy-laden', 'fruit', 'that', 'I', 'may\ngather', 'unto', 'them?\n\nAnd', 'shall', 'my', 'desires', 'flow', 'like', 'a\nfountain', 'that', 'I', 'fill', 'their', 'cups?\n\nAm', 'I', 'harp', 'that', 'hand ...

# %% [markdown]
# Another thing you may have noticed is that some words contain a line break. Let's write a function to split those words. Our function will return the string split on the character `\n`. Write your function in the cell below.

# %%
def line_break(x):
    '''
    Input: A string
    Output: A list of strings split on the line break (\n) character
        
    Example:
    Input: 'the\nbeloved'
    Output: ['the', 'beloved']
    '''
    
    # Your code here:
    
    return x.splitlines()

# %% [markdown]
# Apply the `line_break` function to the `prophet_reference` list. Name the new list `prophet_line`.

# %%
# Your code here:
prophet_line = list(map(line_break, prophet_reference))
print(prophet_line)
# Out:
# [['PROPHET', '', '|Almustafa,'], ['the'], ['chosen'], ['the', 'beloved,'], ['who'], ['was'], ['dawn'], ['unto'], ['own', 'day,'], ['had'], ['waited'], ['twelve'], ['years'], ['city', 'of'], ['Orphalese'], ['ship'], ['that'], ['was'], ['to', 'return'], ['bear'], ['him'], ['back'], ['isle'], ['of', 'his'], ['birth.', '', 'And'], ['twelfth'], ['year,'], ['on'], ['seventh', 'day'], ['Ielool,'], ['month'], ['reaping,'], ['he', 'climbed'], ['hill'], ['without'], ['city'], ['walls', 'and'], ['looked'], ['seaward;'], ['beheld'], ['his', 'ship'], ['coming'], ['mist.', '', 'Then'], ['gates'], ['heart'], ['flung', 'open,'], ['joy'], ['flew'], ['far'], ['over'], ['sea.', 'And'], ['closed'], ['eyes'], ['prayed'], ['the', 'silences'], ['soul.', '', '*****', '', 'But'], ['as'], ['descended'], ['hill,'], ['sadness', 'came'], ['upon'], ['him,'], ['thought'], ['his', 'heart:', '', 'How'], ['shall'], ['I'], ['go'], ['peace'], ['without', 'sorrow?'], ['Nay,'], ['without'], ['wound'], ['the', 'spirit'], ['shall'], ['I'], ['leave'], ['city.'], ['Long', 'were'], ['days'], ['pain'], ['I'], ['have'], ['spent', 'within'], ['its'], ['walls,'], ['long'], ['the', 'nights'], ['aloneness;'], ['who'], ['can'], ['depart', 'from'], ['pain'], ['aloneness'], ['without', 'regret?', '', 'Too'], ['many'], ['fragments'], ['spirit'], ['have'], ['I', 'scattered'], ['these'], ['streets,'], ['too'], ['many', 'are'], ['children'], ['my'], ['longing'], ['that'], ['walk', 'naked'], ['among'], ['these'], ['hills,'], ['I'], ['cannot', 'withdraw'], ['them'], ['without'], ['burden'], ['and', 'an'], ['ache.', '', 'It'], ['garment'], ['I'], ['cast'], ['off'], ['this', 'day,'], ['skin'], ['that'], ['I'], ['tear'], ['my'], ['own', 'hands.', '', 'Nor'], ['thought'], ['I'], ['leave'], ['behind'], ['me,', 'but'], ['heart'], ['made'], ['sweet'], ['hunger'], ['and', 'with'], ['thirst.', '', '*****', '', 'Yet'], ['I'], ['cannot'], ['tarry'], ['longer.', '', 'The'], ['sea'], ['that'], ['calls'], ['things'], ['unto'], ['her', 'calls'], ['me,'], ['I'], ['must'], ['embark.', '', 'For'], ['stay,'], ['though'], ['hours'], ['burn'], ['in', 'the'], ['night,'], ['freeze'], ['crystallize', 'and'], ['be'], ['bound'], ['mould.', '', 'Fain'], ['would'], ['I'], ['take'], ['me'], ['that'], ['is', 'here.'], ['But'], ['how'], ['shall'], ['I?', '', 'A'], ['voice'], ['cannot'], ['carry'], ['tongue'], ["('and\\n', 'the')"], ['lips'], ['that'], ['gave'], ['wings.'], ['Alone', 'must'], ['seek'], ['ether.', '', 'And'], ['alone'], ['without'], ['nest'], ['shall'], ['the', 'eagle'], ['fly'], ['across'], ['sun.', '', '*****', '', 'Now'], ['when'], ['reached'], ['foot'], ['the', 'hill,'], ['turned'], ['again'], ['towards'], ['sea,', 'and'], ['saw'], ['ship'], ['approaching'], ['the', 'harbour,'], ['upon'], ['her'], ['prow'], ['mariners,', 'the'], ['men'], ['own'], ['land.', '', 'And'], ['soul'], ['cried'], ['out'], ['them,'], ['he', 'said:', '', 'Sons'], ['my'], ['ancient'], ['mother,'], ['riders'], ['of', 'the'], ['tides,', '', 'How'], ['often'], ['have'], ['sailed'], ['my'], ['dreams.', 'And'], ['now'], ['come'], ['my'], ['awakening,'], ['which', 'is'], ['my'], ['deeper'], ['dream.', '', 'Ready'], ['am'], ['I'], ['go,'], ['my'], ['eagerness'], ['with', 'sails'], ['full'], ['awaits'], ['wind.', '', 'Only'], ['another'], ['breath'], ['will'], ['I'], ['breathe'], ['in', 'this'], ['still'], ['air,'], ['only'], ['another'], ['loving'], ['look', 'cast'], ['backward,', '', 'And'], ['then'], ['I'], ['shall'], ['stand'], ['among'], ['you,'], ['a', 'seafarer'], ['among'], ['seafarers.'], ['And'], ['you,', 'vast'], ['sea,'], ['sleepless'], ['mother,', '', 'Who'], ['alone'], ['peace'], ['freedom'], ['the', 'river'], ['stream,', '', 'Only'], ['another'], ['winding'], ['will'], ['stream', 'make,'], ['only'], ['another'], ['murmur'], ['glade,', '', 'And'], ['then'], ['shall'], ['I'], ['come'], ['you,'], ['a', 'boundless'], ['drop'], ['boundless'], ['ocean.', '', '*****', '', 'And'], ['as'], ['walked'], ['saw'], ['afar'], ['me ...

# %% [markdown]
# If you look at the elements of `prophet_line`, you will see that the function returned lists and not strings. Our list is now a list of lists. Flatten the list using list comprehension. Assign this new list to `prophet_flat`.

# %%
# Your code here:
prophet_flat = [e for f in prophet_line for e in f if type(f) == list]
print(prophet_flat)
# Out:
# ['PROPHET', '', '|Almustafa,', 'the', 'chosen', 'the', 'beloved,', 'who', 'was', 'dawn', 'unto', 'own', 'day,', 'had', 'waited', 'twelve', 'years', 'city', 'of', 'Orphalese', 'ship', 'that', 'was', 'to', 'return', 'bear', 'him', 'back', 'isle', 'of', 'his', 'birth.', '', 'And', 'twelfth', 'year,', 'on', 'seventh', 'day', 'Ielool,', 'month', 'reaping,', 'he', 'climbed', 'hill', 'without', 'city', 'walls', 'and', 'looked', 'seaward;', 'beheld', 'his', 'ship', 'coming', 'mist.', '', 'Then', 'gates', 'heart', 'flung', 'open,', 'joy', 'flew', 'far', 'over', 'sea.', 'And', 'closed', 'eyes', 'prayed', 'the', 'silences', 'soul.', '', '*****', '', 'But', 'as', 'descended', 'hill,', 'sadness', 'came', 'upon', 'him,', 'thought', 'his', 'heart:', '', 'How', 'shall', 'I', 'go', 'peace', 'without', 'sorrow?', 'Nay,', 'without', 'wound', 'the', 'spirit', 'shall', 'I', 'leave', 'city.', 'Long', 'were', 'days', 'pain', 'I', 'have', 'spent', 'within', 'its', 'walls,', 'long', 'the', 'nights', 'aloneness;', 'who', 'can', 'depart', 'from', 'pain', 'aloneness', 'without', 'regret?', '', 'Too', 'many', 'fragments', 'spirit', 'have', 'I', 'scattered', 'these', 'streets,', 'too', 'many', 'are', 'children', 'my', 'longing', 'that', 'walk', 'naked', 'among', 'these', 'hills,', 'I', 'cannot', 'withdraw', 'them', 'without', 'burden', 'and', 'an', 'ache.', '', 'It', 'garment', 'I', 'cast', 'off', 'this', 'day,', 'skin', 'that', 'I', 'tear', 'my', 'own', 'hands.', '', 'Nor', 'thought', 'I', 'leave', 'behind', 'me,', 'but', 'heart', 'made', 'sweet', 'hunger', 'and', 'with', 'thirst.', '', '*****', '', 'Yet', 'I', 'cannot', 'tarry', 'longer.', '', 'The', 'sea', 'that', 'calls', 'things', 'unto', 'her', 'calls', 'me,', 'I', 'must', 'embark.', '', 'For', 'stay,', 'though', 'hours', 'burn', 'in', 'the', 'night,', 'freeze', 'crystallize', 'and', 'be', 'bound', 'mould.', '', 'Fain', 'would', 'I', 'take', 'me', 'that', 'is', 'here.', 'But', 'how', 'shall', 'I?', '', 'A', 'voice', 'cannot', 'carry', 'tongue', "('and\\n', 'the')", 'lips', 'that', 'gave', 'wings.', 'Alone', 'must', 'seek', 'ether.', '', 'And', 'alone', 'without', 'nest', 'shall', 'the', 'eagle', 'fly', 'across', 'sun.', '', '*****', '', 'Now', 'when', 'reached', 'foot', 'the', 'hill,', 'turned', 'again', 'towards', 'sea,', 'and', 'saw', 'ship', 'approaching', 'the', 'harbour,', 'upon', 'her', 'prow', 'mariners,', 'the', 'men', 'own', 'land.', '', 'And', 'soul', 'cried', 'out', 'them,', 'he', 'said:', '', 'Sons', 'my', 'ancient', 'mother,', 'riders', 'of', 'the', 'tides,', '', 'How', 'often', 'have', 'sailed', 'my', 'dreams.', 'And', 'now', 'come', 'my', 'awakening,', 'which', 'is', 'my', 'deeper', 'dream.', '', 'Ready', 'am', 'I', 'go,', 'my', 'eagerness', 'with', 'sails', 'full', 'awaits', 'wind.', '', 'Only', 'another', 'breath', 'will', 'I', 'breathe', 'in', 'this', 'still', 'air,', 'only', 'another', 'loving', 'look', 'cast', 'backward,', '', 'And', 'then', 'I', 'shall', 'stand', 'among', 'you,', 'a', 'seafarer', 'among', 'seafarers.', 'And', 'you,', 'vast', 'sea,', 'sleepless', 'mother,', '', 'Who', 'alone', 'peace', 'freedom', 'the', 'river', 'stream,', '', 'Only', 'another', 'winding', 'will', 'stream', 'make,', 'only', 'another', 'murmur', 'glade,', '', 'And', 'then', 'shall', 'I', 'come', 'you,', 'a', 'boundless', 'drop', 'boundless', 'ocean.', '', '*****', '', 'And', 'as', 'walked', 'saw', 'afar', 'men', 'and', 'women', 'leaving', 'their', 'fields', 'their', 'vineyards', 'hastening', 'towards', 'city', 'gates.', '', 'And', 'heard', 'their', 'voices', 'calling', 'his', 'name,', 'shouting', 'field', 'field', 'telling', 'one', 'another', 'coming', 'his', 'ship.', '', 'And', 'said', 'himself:', '', 'Shall', 'day', 'parting', 'be', 'day', 'of', 'gathering?', '', 'And', 'shall', 'be', 'said', 'that', 'my', 'eve', 'was', 'in', 'truth', 'my', 'dawn?', '', 'And', 'what', 'shall', 'I', 'unto', 'him', 'who', 'has', 'left', 'plough', 'midfurrow,', 'to', 'him', 'who', 'has', 'stopped', 'wheel', 'his', ' ...

# %% [markdown]
# # Challenge 2 - Filtering
#
# When printing out a few words from the book, we see that there are words that we may not want to keep if we choose to analyze the corpus of text. Below is a list of words that we would like to get rid of. Create a function that will return false if it contains a word from the list of words specified and true otherwise.

# %%
def word_filter(x):
    '''
    Input: A string
    Output: true if the word is not in the specified list and false if the word is in the list
        
    Example:
    word list = ['and', 'the']
    Input: 'and'
    Output: False
    
    Input: 'John'
    Output: True
    '''
    
    word_list = ['and', 'the', 'a', 'an', '']
    
    # Your code here:
    return x not in word_list

# %%
prophet_filter= list(filter(word_filter, prophet_flat))
print(prophet_filter)
# Out:
# ['PROPHET', '|Almustafa,', 'chosen', 'beloved,', 'who', 'was', 'dawn', 'unto', 'own', 'day,', 'had', 'waited', 'twelve', 'years', 'city', 'of', 'Orphalese', 'ship', 'that', 'was', 'to', 'return', 'bear', 'him', 'back', 'isle', 'of', 'his', 'birth.', 'And', 'twelfth', 'year,', 'on', 'seventh', 'day', 'Ielool,', 'month', 'reaping,', 'he', 'climbed', 'hill', 'without', 'city', 'walls', 'looked', 'seaward;', 'beheld', 'his', 'ship', 'coming', 'mist.', 'Then', 'gates', 'heart', 'flung', 'open,', 'joy', 'flew', 'far', 'over', 'sea.', 'And', 'closed', 'eyes', 'prayed', 'silences', 'soul.', '*****', 'But', 'as', 'descended', 'hill,', 'sadness', 'came', 'upon', 'him,', 'thought', 'his', 'heart:', 'How', 'shall', 'I', 'go', 'peace', 'without', 'sorrow?', 'Nay,', 'without', 'wound', 'spirit', 'shall', 'I', 'leave', 'city.', 'Long', 'were', 'days', 'pain', 'I', 'have', 'spent', 'within', 'its', 'walls,', 'long', 'nights', 'aloneness;', 'who', 'can', 'depart', 'from', 'pain', 'aloneness', 'without', 'regret?', 'Too', 'many', 'fragments', 'spirit', 'have', 'I', 'scattered', 'these', 'streets,', 'too', 'many', 'are', 'children', 'my', 'longing', 'that', 'walk', 'naked', 'among', 'these', 'hills,', 'I', 'cannot', 'withdraw', 'them', 'without', 'burden', 'ache.', 'It', 'garment', 'I', 'cast', 'off', 'this', 'day,', 'skin', 'that', 'I', 'tear', 'my', 'own', 'hands.', 'Nor', 'thought', 'I', 'leave', 'behind', 'me,', 'but', 'heart', 'made', 'sweet', 'hunger', 'with', 'thirst.', '*****', 'Yet', 'I', 'cannot', 'tarry', 'longer.', 'The', 'sea', 'that', 'calls', 'things', 'unto', 'her', 'calls', 'me,', 'I', 'must', 'embark.', 'For', 'stay,', 'though', 'hours', 'burn', 'in', 'night,', 'freeze', 'crystallize', 'be', 'bound', 'mould.', 'Fain', 'would', 'I', 'take', 'me', 'that', 'is', 'here.', 'But', 'how', 'shall', 'I?', 'A', 'voice', 'cannot', 'carry', 'tongue', "('and\\n', 'the')", 'lips', 'that', 'gave', 'wings.', 'Alone', 'must', 'seek', 'ether.', 'And', 'alone', 'without', 'nest', 'shall', 'eagle', 'fly', 'across', 'sun.', '*****', 'Now', 'when', 'reached', 'foot', 'hill,', 'turned', 'again', 'towards', 'sea,', 'saw', 'ship', 'approaching', 'harbour,', 'upon', 'her', 'prow', 'mariners,', 'men', 'own', 'land.', 'And', 'soul', 'cried', 'out', 'them,', 'he', 'said:', 'Sons', 'my', 'ancient', 'mother,', 'riders', 'of', 'tides,', 'How', 'often', 'have', 'sailed', 'my', 'dreams.', 'And', 'now', 'come', 'my', 'awakening,', 'which', 'is', 'my', 'deeper', 'dream.', 'Ready', 'am', 'I', 'go,', 'my', 'eagerness', 'with', 'sails', 'full', 'awaits', 'wind.', 'Only', 'another', 'breath', 'will', 'I', 'breathe', 'in', 'this', 'still', 'air,', 'only', 'another', 'loving', 'look', 'cast', 'backward,', 'And', 'then', 'I', 'shall', 'stand', 'among', 'you,', 'seafarer', 'among', 'seafarers.', 'And', 'you,', 'vast', 'sea,', 'sleepless', 'mother,', 'Who', 'alone', 'peace', 'freedom', 'river', 'stream,', 'Only', 'another', 'winding', 'will', 'stream', 'make,', 'only', 'another', 'murmur', 'glade,', 'And', 'then', 'shall', 'I', 'come', 'you,', 'boundless', 'drop', 'boundless', 'ocean.', '*****', 'And', 'as', 'walked', 'saw', 'afar', 'men', 'women', 'leaving', 'their', 'fields', 'their', 'vineyards', 'hastening', 'towards', 'city', 'gates.', 'And', 'heard', 'their', 'voices', 'calling', 'his', 'name,', 'shouting', 'field', 'field', 'telling', 'one', 'another', 'coming', 'his', 'ship.', 'And', 'said', 'himself:', 'Shall', 'day', 'parting', 'be', 'day', 'of', 'gathering?', 'And', 'shall', 'be', 'said', 'that', 'my', 'eve', 'was', 'in', 'truth', 'my', 'dawn?', 'And', 'what', 'shall', 'I', 'unto', 'him', 'who', 'has', 'left', 'plough', 'midfurrow,', 'to', 'him', 'who', 'has', 'stopped', 'wheel', 'his', 'winepress?', 'Shall', 'my', 'heart', 'become', 'tree', 'heavy-laden', 'fruit', 'that', 'I', 'may', 'gather', 'unto', 'them?', 'And', 'shall', 'my', 'desires', 'flow', 'like', 'fountain', 'that', 'I', 'fill', 'their', 'cups?', 'Am', 'I', 'harp', 'that', 'hand', 'mighty', 'may',  ...

# %% [markdown]
# Use the `filter()` function to filter out the words speficied in the `word_filter()` function. Store the filtered list in the variable `prophet_filter`.

# %% [markdown]
# # Bonus Challenge - Part 1
#
# Rewrite the `word_filter` function above to not be case sensitive.

# %%
def word_filter_case(x):
   
    word_list = ['and', 'the', 'a', 'an','']
    
    # Your code here:
    return x.lower() not in word_list

# %%
prophet_filter= list(filter(word_filter_case, prophet_flat))
print(prophet_filter)
# Out:
# ['PROPHET', '|Almustafa,', 'chosen', 'beloved,', 'who', 'was', 'dawn', 'unto', 'own', 'day,', 'had', 'waited', 'twelve', 'years', 'city', 'of', 'Orphalese', 'ship', 'that', 'was', 'to', 'return', 'bear', 'him', 'back', 'isle', 'of', 'his', 'birth.', 'twelfth', 'year,', 'on', 'seventh', 'day', 'Ielool,', 'month', 'reaping,', 'he', 'climbed', 'hill', 'without', 'city', 'walls', 'looked', 'seaward;', 'beheld', 'his', 'ship', 'coming', 'mist.', 'Then', 'gates', 'heart', 'flung', 'open,', 'joy', 'flew', 'far', 'over', 'sea.', 'closed', 'eyes', 'prayed', 'silences', 'soul.', '*****', 'But', 'as', 'descended', 'hill,', 'sadness', 'came', 'upon', 'him,', 'thought', 'his', 'heart:', 'How', 'shall', 'I', 'go', 'peace', 'without', 'sorrow?', 'Nay,', 'without', 'wound', 'spirit', 'shall', 'I', 'leave', 'city.', 'Long', 'were', 'days', 'pain', 'I', 'have', 'spent', 'within', 'its', 'walls,', 'long', 'nights', 'aloneness;', 'who', 'can', 'depart', 'from', 'pain', 'aloneness', 'without', 'regret?', 'Too', 'many', 'fragments', 'spirit', 'have', 'I', 'scattered', 'these', 'streets,', 'too', 'many', 'are', 'children', 'my', 'longing', 'that', 'walk', 'naked', 'among', 'these', 'hills,', 'I', 'cannot', 'withdraw', 'them', 'without', 'burden', 'ache.', 'It', 'garment', 'I', 'cast', 'off', 'this', 'day,', 'skin', 'that', 'I', 'tear', 'my', 'own', 'hands.', 'Nor', 'thought', 'I', 'leave', 'behind', 'me,', 'but', 'heart', 'made', 'sweet', 'hunger', 'with', 'thirst.', '*****', 'Yet', 'I', 'cannot', 'tarry', 'longer.', 'sea', 'that', 'calls', 'things', 'unto', 'her', 'calls', 'me,', 'I', 'must', 'embark.', 'For', 'stay,', 'though', 'hours', 'burn', 'in', 'night,', 'freeze', 'crystallize', 'be', 'bound', 'mould.', 'Fain', 'would', 'I', 'take', 'me', 'that', 'is', 'here.', 'But', 'how', 'shall', 'I?', 'voice', 'cannot', 'carry', 'tongue', "('and\\n', 'the')", 'lips', 'that', 'gave', 'wings.', 'Alone', 'must', 'seek', 'ether.', 'alone', 'without', 'nest', 'shall', 'eagle', 'fly', 'across', 'sun.', '*****', 'Now', 'when', 'reached', 'foot', 'hill,', 'turned', 'again', 'towards', 'sea,', 'saw', 'ship', 'approaching', 'harbour,', 'upon', 'her', 'prow', 'mariners,', 'men', 'own', 'land.', 'soul', 'cried', 'out', 'them,', 'he', 'said:', 'Sons', 'my', 'ancient', 'mother,', 'riders', 'of', 'tides,', 'How', 'often', 'have', 'sailed', 'my', 'dreams.', 'now', 'come', 'my', 'awakening,', 'which', 'is', 'my', 'deeper', 'dream.', 'Ready', 'am', 'I', 'go,', 'my', 'eagerness', 'with', 'sails', 'full', 'awaits', 'wind.', 'Only', 'another', 'breath', 'will', 'I', 'breathe', 'in', 'this', 'still', 'air,', 'only', 'another', 'loving', 'look', 'cast', 'backward,', 'then', 'I', 'shall', 'stand', 'among', 'you,', 'seafarer', 'among', 'seafarers.', 'you,', 'vast', 'sea,', 'sleepless', 'mother,', 'Who', 'alone', 'peace', 'freedom', 'river', 'stream,', 'Only', 'another', 'winding', 'will', 'stream', 'make,', 'only', 'another', 'murmur', 'glade,', 'then', 'shall', 'I', 'come', 'you,', 'boundless', 'drop', 'boundless', 'ocean.', '*****', 'as', 'walked', 'saw', 'afar', 'men', 'women', 'leaving', 'their', 'fields', 'their', 'vineyards', 'hastening', 'towards', 'city', 'gates.', 'heard', 'their', 'voices', 'calling', 'his', 'name,', 'shouting', 'field', 'field', 'telling', 'one', 'another', 'coming', 'his', 'ship.', 'said', 'himself:', 'Shall', 'day', 'parting', 'be', 'day', 'of', 'gathering?', 'shall', 'be', 'said', 'that', 'my', 'eve', 'was', 'in', 'truth', 'my', 'dawn?', 'what', 'shall', 'I', 'unto', 'him', 'who', 'has', 'left', 'plough', 'midfurrow,', 'to', 'him', 'who', 'has', 'stopped', 'wheel', 'his', 'winepress?', 'Shall', 'my', 'heart', 'become', 'tree', 'heavy-laden', 'fruit', 'that', 'I', 'may', 'gather', 'unto', 'them?', 'shall', 'my', 'desires', 'flow', 'like', 'fountain', 'that', 'I', 'fill', 'their', 'cups?', 'Am', 'I', 'harp', 'that', 'hand', 'mighty', 'may', 'touch', 'me,', 'flute', 'that', 'breath', 'may', 'pass', 'through', 'me?', 'seeker', 'silences', 'am', 'I,',  ...

# %% [markdown]
# # Challenge 3 - Reducing
#
# #### Now that we have significantly cleaned up our text corpus, let's use the `reduce()` function to put the words back together into one long string separated by spaces.
#
# We will start by writing a function that takes two strings and concatenates them together with a space between the two strings.

# %%
def concat_space(a, b):
    '''
    Input:Two strings
    Output: A single string separated by a space
        
    Example:
    Input: 'John', 'Smith'
    Output: 'John Smith'
    '''
    
    # Your code here:
    return a + ' ' + b

# %% [markdown]
# Use the function above to reduce the text corpus in the list `prophet_filter` into a single string. Assign this new string to the variable `prophet_string`.

# %%
# Your code here:
prophet_string = reduce(concat_space, prophet_filter) 
print(prophet_string)
# Out:
# PROPHET |Almustafa, chosen beloved, who was dawn unto own day, had waited twelve years city of Orphalese ship that was to return bear him back isle of his birth. twelfth year, on seventh day Ielool, month reaping, he climbed hill without city walls looked seaward; beheld his ship coming mist. Then gates heart flung open, joy flew far over sea. closed eyes prayed silences soul. ***** But as descended hill, sadness came upon him, thought his heart: How shall I go peace without sorrow? Nay, without wound spirit shall I leave city. Long were days pain I have spent within its walls, long nights aloneness; who can depart from pain aloneness without regret? Too many fragments spirit have I scattered these streets, too many are children my longing that walk naked among these hills, I cannot withdraw them without burden ache. It garment I cast off this day, skin that I tear my own hands. Nor thought I leave behind me, but heart made sweet hunger with thirst. ***** Yet I cannot tarry longer. sea that calls things unto her calls me, I must embark. For stay, though hours burn in night, freeze crystallize be bound mould. Fain would I take me that is here. But how shall I? voice cannot carry tongue ('and\n', 'the') lips that gave wings. Alone must seek ether. alone without nest shall eagle fly across sun. ***** Now when reached foot hill, turned again towards sea, saw ship approaching harbour, upon her prow mariners, men own land. soul cried out them, he said: Sons my ancient mother, riders of tides, How often have sailed my dreams. now come my awakening, which is my deeper dream. Ready am I go, my eagerness with sails full awaits wind. Only another breath will I breathe in this still air, only another loving look cast backward, then I shall stand among you, seafarer among seafarers. you, vast sea, sleepless mother, Who alone peace freedom river stream, Only another winding will stream make, only another murmur glade, then shall I come you, boundless drop boundless ocean. ***** as walked saw afar men women leaving their fields their vineyards hastening towards city gates. heard their voices calling his name, shouting field field telling one another coming his ship. said himself: Shall day parting be day of gathering? shall be said that my eve was in truth my dawn? what shall I unto him who has left plough midfurrow, to him who has stopped wheel his winepress? Shall my heart become tree heavy-laden fruit that I may gather unto them? shall my desires flow like fountain that I fill their cups? Am I harp that hand mighty may touch me, flute that breath may pass through me? seeker silences am I, what treasure have I found silences that I may dispense confidence? If my day harvest, what fields have I sowed seed, in what unremembered seasons? If indeed be hour which I lift up my lantern, my flame that shall burn therein. Empty dark shall I raise my lantern, guardian night shall fill it oil shall light also. ***** These things said words. But much in heart remained unsaid. he himself speak deeper secret. ***** [Illustration: 0020] when entered into city all people meet him, they were crying out him as one voice. elders city stood forth said: Go yet us. noontide have been our twilight, your youth has given us dreams dream. No stranger among us, nor guest, our son our dearly beloved. Suffer yet our eyes hunger for your face. ***** priests priestesses said unto him: Let waves sea separate us now, years have spent our midst become memory. You have walked among us ('spirit,\n', 'and') your shadow has been light upon our faces. Much have we loved you. But speechless was our love, veils has been veiled. Yet now cries aloud unto you, would stand revealed you. ever has been that love knows not its own depth until hour of separation. ***** others also entreated him. But answered them not. He only bent his head; who stood near saw his tears falling upon breast. people proceeded towards square temple. there out sanctuary woman whose name was Almitra. she was s ...

# %% [markdown]
# # Challenge 4 - Applying Functions to DataFrames
#
# #### Our next step is to use the apply function to a dataframe and transform all cells.
#
# To do this, we will load a dataset below and then write a function that will perform the transformation.

# %%
# Run this code:

# The dataset below contains information about pollution from PM2.5 particles in Beijing 

url = "https://archive.ics.uci.edu/ml/machine-learning-databases/00381/PRSA_data_2010.1.1-2014.12.31.csv"
pm25 = pd.read_csv(url)

# %% [markdown]
# Let's look at the data using the `head()` function.

# %%
# Your code here:
pm25.head()
# Out:
#    No  year  month  day  hour  pm2.5  DEWP  TEMP    PRES cbwd    Iws  Is  Ir
# 0   1  2010      1    1     0    NaN   -21 -11.0  1021.0   NW   1.79   0   0
# 1   2  2010      1    1     1    NaN   -21 -12.0  1020.0   NW   4.92   0   0
# 2   3  2010      1    1     2    NaN   -21 -11.0  1019.0   NW   6.71   0   0
# 3   4  2010      1    1     3    NaN   -21 -14.0  1019.0   NW   9.84   0   0
# 4   5  2010      1    1     4    NaN   -20 -12.0  1018.0   NW  12.97   0   0

# %% [markdown]
# The next step is to create a function that divides a cell by 24 to produce an hourly figure. Write the function below.

# %%
def hourly(x):
    '''
    Input: A numerical value
    Output: The value divided by 24
        
    Example:
    Input: 48
    Output: 2.0
    '''
    
    # Your code here:
    return x/24

# %% [markdown]
# Apply this function to the columns `Iws`, `Is`, and `Ir`. Store this new dataframe in the variable `pm25_hourly`.

# %%
# Your code here:
pm25_hourly = pd.DataFrame(map(hourly, [pm25['Iws'], pm25['Is'], pm25['Ir']]))
pm25_hourly.T
# Out:
#              Iws   Is   Ir
# 0       0.074583  0.0  0.0
# 1       0.205000  0.0  0.0
# 2       0.279583  0.0  0.0
# 3       0.410000  0.0  0.0
# 4       0.540417  0.0  0.0
# ...          ...  ...  ...
# 43819   9.665417  0.0  0.0
# 43820   9.907500  0.0  0.0
# 43821  10.112500  0.0  0.0
# 43822  10.280000  0.0  0.0
# 43823  10.410417  0.0  0.0
#
# [43824 rows x 3 columns]

# %% [markdown]
# #### Our last challenge will be to create an aggregate function and apply it to a select group of columns in our dataframe.
#
# Write a function that returns the standard deviation of a column divided by the length of a column minus 1. Since we are using pandas, do not use the `len()` function. One alternative is to use `count()`. Also, use the numpy version of standard deviation.

# %%
def sample_sd(x):
    '''
    Input: A Pandas series of values
    Output: the standard deviation divided by the number of elements in the series
        
    Example:
    Input: pd.Series([1,2,3,4])
    Output: 0.3726779962
    '''
    
    # Your code here:
    return np.std(x) / (pd.Series.count(x) - 1)

# %%
print(sample_sd(pm25['Iws']))
# Out:
# 0.0011411830334976838
