# %% [markdown]
# # Before your start:
# - Read the README.md file
# - Comment as much as you can and use the resources in the README.md file
# - Happy learning!

# %%
# import reduce from functools, numpy and pandas
import numpy as np
import pandas as pd

# %% [markdown]
# # Challenge 1 - Mapping
#
# #### We will use the map function to clean up a words in a book.
#
# In the following cell, we will read a text file containing the book The Prophet by Khalil Gibran.

# %%
# Run this code:
location = '../58585-0.txt'
with open(location, 'r', encoding="utf8") as f:
    prophet = f.read().split(' ')

# %% [markdown]
# #### Let's remove the first 568 words since they contain information about the book but are not part of the book itself.
#
# Do this by removing from `prophet` elements 0 through 567 of the list (you can also do this by keeping elements 568 through the last element).

# %%
# Your code here:
lista = prophet[567:]

# %% [markdown]
# If you look through the words, you will find that many words have a reference attached to them. For example, let's look at words 1 through 10.

# %%
# Your code here:
print(lista[0:10])
# Out:
# ['Farewell................92\n\n\n\n\nTHE', 'PROPHET\n\n|Almustafa,', 'the{7}', 'chosen', 'and', 'the\nbeloved,', 'who', 'was', 'a', 'dawn']

# %% [markdown]
# #### The next step is to create a function that will remove references.
#
# We will do this by splitting the string on the `{` character and keeping only the part before this character. Write your function below.

# %%
def reference(x):
    if "{" in x:
        trozo1 = x.split("{")
        trozo2 = x.split("}")
        return trozo1[0] + trozo2[-1]
    else:
        return x

# %% [markdown]
# Now that we have our function, use the `map()` function to apply this function to our book, The Prophet. Return the resulting list to a new list called `prophet_reference`

# %%
prophet_reference = list(map(reference,prophet))
print(prophet_reference)
# Out:
# ['\ufeffThe\ufeffThe', 'ProjectProject', 'GutenbergGutenberg', 'EBookEBook', 'ofof', 'TheThe', 'Prophet,Prophet,', 'byby', 'KahlilKahlil', 'Gibran\n\nThisGibran\n\nThis', 'eBookeBook', 'isis', 'forfor', 'thethe', 'useuse', 'ofof', 'anyoneanyone', 'anywhereanywhere', 'inin', 'thethe', 'UnitedUnited', 'StatesStates', 'and\nmostand\nmost', 'otherother', 'partsparts', 'ofof', 'thethe', 'worldworld', 'atat', 'nono', 'costcost', 'andand', 'withwith', 'almostalmost', 'nono', 'restrictions\nwhatsoever.restrictions\nwhatsoever.', '', 'YouYou', 'maymay', 'copycopy', 'it,it,', 'givegive', 'itit', 'awayaway', 'oror', 're-usere-use', 'itit', 'underunder', 'thethe', 'terms\nofterms\nof', 'thethe', 'ProjectProject', 'GutenbergGutenberg', 'LicenseLicense', 'includedincluded', 'withwith', 'thisthis', 'eBookeBook', 'oror', 'onlineonline', 'at\nwww.gutenberg.org.at\nwww.gutenberg.org.', '', 'IfIf', 'youyou', 'areare', 'notnot', 'locatedlocated', 'inin', 'thethe', 'UnitedUnited', 'States,States,', "you'll\nhaveyou'll\nhave", 'toto', 'checkcheck', 'thethe', 'lawslaws', 'ofof', 'thethe', 'countrycountry', 'wherewhere', 'youyou', 'areare', 'locatedlocated', 'beforebefore', 'using\nthisusing\nthis', 'ebook.\n\n\n\nTitle:ebook.\n\n\n\nTitle:', 'TheThe', 'Prophet\n\nAuthor:Prophet\n\nAuthor:', 'KahlilKahlil', 'Gibran\n\nReleaseGibran\n\nRelease', 'Date:Date:', 'JanuaryJanuary', '1,1,', '20192019', '[EBook[EBook', '#58585]\nLast#58585]\nLast', 'Updated:Updated:', 'JanuaryJanuary', '3,3,', '2018\n\n\nLanguage:2018\n\n\nLanguage:', 'English\n\nCharacterEnglish\n\nCharacter', 'setset', 'encoding:encoding:', 'UTF-8\n\n***UTF-8\n\n***', 'STARTSTART', 'OFOF', 'THISTHIS', 'PROJECTPROJECT', 'GUTENBERGGUTENBERG', 'EBOOKEBOOK', 'THETHE', 'PROPHETPROPHET', '***\n\n\n\n\nProduced***\n\n\n\n\nProduced', 'byby', 'DavidDavid', 'WidgerWidger', 'fromfrom', 'pagepage', 'imagesimages', 'generously\nprovidedgenerously\nprovided', 'byby', 'thethe', 'InternetInternet', "Archive\n\n\nTranscriber'sArchive\n\n\nTranscriber's", 'Note:Note:', 'PagePage', 'numbers,numbers,', 'ie:ie:', ',', 'areare', 'includedincluded', 'inin', 'this\nutf-8this\nutf-8', 'texttext', 'file.file.', 'ForFor', 'thosethose', 'wishingwishing', 'toto', 'useuse', 'aa', 'texttext', 'filefile', 'unencumbered\nwithunencumbered\nwith', 'pagepage', 'numbersnumbers', 'openopen', 'oror', 'downloaddownload', 'thethe', 'Latin-1Latin-1', 'filefile', '58585-8.txt.\n\n\n\n\n\n\n\nTHE58585-8.txt.\n\n\n\n\n\n\n\nTHE', 'PROPHET\n\nByPROPHET\n\nBy', 'KahlilKahlil', 'Gibran\n\nNewGibran\n\nNew', 'York:York:', 'AlfredAlfred', 'A.A.', 'Knopf\n\n1923\n\n_TheKnopf\n\n1923\n\n_The', 'TwelveTwelve', 'IllustrationsIllustrations', 'InIn', 'ThisThis', 'Volume\nAreVolume\nAre', 'ReproducedReproduced', 'FromFrom', 'OriginalOriginal', 'DrawingsDrawings', 'By\nTheBy\nThe', 'Author_\n\n\n“HisAuthor_\n\n\n“His', 'powerpower', 'camecame', 'fromfrom', 'somesome', 'greatgreat', 'reservoir\nofreservoir\nof', 'spiritualspiritual', 'lifelife', 'elseelse', 'itit', 'couldcould', 'notnot', 'have\nbeenhave\nbeen', 'soso', 'universaluniversal', 'andand', 'soso', 'potent,potent,', 'butbut', 'the\nmajestythe\nmajesty', 'andand', 'beautybeauty', 'ofof', 'thethe', 'languagelanguage', 'with\nwhichwith\nwhich', 'hehe', 'clothedclothed', 'itit', 'werewere', 'allall', 'hishis', 'own?”\n\n--Claudeown?”\n\n--Claude', 'Bragdon\n\n\nTHEBragdon\n\n\nTHE', 'BOOKSBOOKS', 'OFOF', 'KAHLILKAHLIL', 'GIBRAN\n\nTheGIBRAN\n\nThe', 'Madman.Madman.', '19181918', 'TwentyTwenty', 'Drawings.Drawings.', '1919\nThe1919\nThe', 'Forerunner.Forerunner.', '19201920', 'TheThe', 'Prophet.Prophet.', '1923\nSand1923\nSand', 'andand', 'Foam.Foam.', '19261926', 'JesusJesus', 'thethe', 'SonSon', 'of\nMan.of\nMan.', '19281928', 'TheThe', 'ForthForth', 'Gods.Gods.', '19311931', 'The\nWanderer.The\nWanderer.', '19321932', 'TheThe', 'GardenGarden', 'ofof', 'thethe', 'Prophet\n1933Prophet\n1933', 'ProseProse', 'Poems.Poems.', '19341934', 'NymphsNymphs', 'ofof', 'the\nValley.the\nValley.', '194 ...

# %% [markdown]
# Another thing you may have noticed is that some words contain a line break. Let's write a function to split those words. Our function will return the string split on the character `\n`. Write your function in the cell below.

# %%
def line_break(x):
    return x.split("\n")

# %% [markdown]
# Apply the `line_break` function to the `prophet_reference` list. Name the new list `prophet_line`.

# %%
# Your code here:
prophet_line = list(map(line_break,prophet_reference))
print(prophet_line)
# Out:
# [['\ufeffThe\ufeffThe'], ['ProjectProject'], ['GutenbergGutenberg'], ['EBookEBook'], ['ofof'], ['TheThe'], ['Prophet,Prophet,'], ['byby'], ['KahlilKahlil'], ['Gibran', '', 'ThisGibran', '', 'This'], ['eBookeBook'], ['isis'], ['forfor'], ['thethe'], ['useuse'], ['ofof'], ['anyoneanyone'], ['anywhereanywhere'], ['inin'], ['thethe'], ['UnitedUnited'], ['StatesStates'], ['and', 'mostand', 'most'], ['otherother'], ['partsparts'], ['ofof'], ['thethe'], ['worldworld'], ['atat'], ['nono'], ['costcost'], ['andand'], ['withwith'], ['almostalmost'], ['nono'], ['restrictions', 'whatsoever.restrictions', 'whatsoever.'], [''], ['YouYou'], ['maymay'], ['copycopy'], ['it,it,'], ['givegive'], ['itit'], ['awayaway'], ['oror'], ['re-usere-use'], ['itit'], ['underunder'], ['thethe'], ['terms', 'ofterms', 'of'], ['thethe'], ['ProjectProject'], ['GutenbergGutenberg'], ['LicenseLicense'], ['includedincluded'], ['withwith'], ['thisthis'], ['eBookeBook'], ['oror'], ['onlineonline'], ['at', 'www.gutenberg.org.at', 'www.gutenberg.org.'], [''], ['IfIf'], ['youyou'], ['areare'], ['notnot'], ['locatedlocated'], ['inin'], ['thethe'], ['UnitedUnited'], ['States,States,'], ["you'll", "haveyou'll", 'have'], ['toto'], ['checkcheck'], ['thethe'], ['lawslaws'], ['ofof'], ['thethe'], ['countrycountry'], ['wherewhere'], ['youyou'], ['areare'], ['locatedlocated'], ['beforebefore'], ['using', 'thisusing', 'this'], ['ebook.', '', '', '', 'Title:ebook.', '', '', '', 'Title:'], ['TheThe'], ['Prophet', '', 'Author:Prophet', '', 'Author:'], ['KahlilKahlil'], ['Gibran', '', 'ReleaseGibran', '', 'Release'], ['Date:Date:'], ['JanuaryJanuary'], ['1,1,'], ['20192019'], ['[EBook[EBook'], ['#58585]', 'Last#58585]', 'Last'], ['Updated:Updated:'], ['JanuaryJanuary'], ['3,3,'], ['2018', '', '', 'Language:2018', '', '', 'Language:'], ['English', '', 'CharacterEnglish', '', 'Character'], ['setset'], ['encoding:encoding:'], ['UTF-8', '', '***UTF-8', '', '***'], ['STARTSTART'], ['OFOF'], ['THISTHIS'], ['PROJECTPROJECT'], ['GUTENBERGGUTENBERG'], ['EBOOKEBOOK'], ['THETHE'], ['PROPHETPROPHET'], ['***', '', '', '', '', 'Produced***', '', '', '', '', 'Produced'], ['byby'], ['DavidDavid'], ['WidgerWidger'], ['fromfrom'], ['pagepage'], ['imagesimages'], ['generously', 'providedgenerously', 'provided'], ['byby'], ['thethe'], ['InternetInternet'], ['Archive', '', '', "Transcriber'sArchive", '', '', "Transcriber's"], ['Note:Note:'], ['PagePage'], ['numbers,numbers,'], ['ie:ie:'], [','], ['areare'], ['includedincluded'], ['inin'], ['this', 'utf-8this', 'utf-8'], ['texttext'], ['file.file.'], ['ForFor'], ['thosethose'], ['wishingwishing'], ['toto'], ['useuse'], ['aa'], ['texttext'], ['filefile'], ['unencumbered', 'withunencumbered', 'with'], ['pagepage'], ['numbersnumbers'], ['openopen'], ['oror'], ['downloaddownload'], ['thethe'], ['Latin-1Latin-1'], ['filefile'], ['58585-8.txt.', '', '', '', '', '', '', '', 'THE58585-8.txt.', '', '', '', '', '', '', '', 'THE'], ['PROPHET', '', 'ByPROPHET', '', 'By'], ['KahlilKahlil'], ['Gibran', '', 'NewGibran', '', 'New'], ['York:York:'], ['AlfredAlfred'], ['A.A.'], ['Knopf', '', '1923', '', '_TheKnopf', '', '1923', '', '_The'], ['TwelveTwelve'], ['IllustrationsIllustrations'], ['InIn'], ['ThisThis'], ['Volume', 'AreVolume', 'Are'], ['ReproducedReproduced'], ['FromFrom'], ['OriginalOriginal'], ['DrawingsDrawings'], ['By', 'TheBy', 'The'], ['Author_', '', '', '“HisAuthor_', '', '', '“His'], ['powerpower'], ['camecame'], ['fromfrom'], ['somesome'], ['greatgreat'], ['reservoir', 'ofreservoir', 'of'], ['spiritualspiritual'], ['lifelife'], ['elseelse'], ['itit'], ['couldcould'], ['notnot'], ['have', 'beenhave', 'been'], ['soso'], ['universaluniversal'], ['andand'], ['soso'], ['potent,potent,'], ['butbut'], ['the', 'majestythe', 'majesty'], ['andand'], ['beautybeauty'], ['ofof'], ['thethe'], ['languagelanguage'], ['with', 'whichwith', 'which'], ['hehe'], ['clothedclothed'], ['itit'], ['werewere'], ['allall'], ['hishis'], ['own?”', '', '--Claudeown?”', '', '--Claude'] ...

# %% [markdown]
# If you look at the elements of `prophet_line`, you will see that the function returned lists and not strings. Our list is now a list of lists. Flatten the list using list comprehension. Assign this new list to `prophet_flat`.

# %%
# Your code here:
prophet_flat = [elemento for lista in prophet_line for elemento in lista]
print(prophet_flat)
# Out:
# ['\ufeffThe\ufeffThe', 'ProjectProject', 'GutenbergGutenberg', 'EBookEBook', 'ofof', 'TheThe', 'Prophet,Prophet,', 'byby', 'KahlilKahlil', 'Gibran', '', 'ThisGibran', '', 'This', 'eBookeBook', 'isis', 'forfor', 'thethe', 'useuse', 'ofof', 'anyoneanyone', 'anywhereanywhere', 'inin', 'thethe', 'UnitedUnited', 'StatesStates', 'and', 'mostand', 'most', 'otherother', 'partsparts', 'ofof', 'thethe', 'worldworld', 'atat', 'nono', 'costcost', 'andand', 'withwith', 'almostalmost', 'nono', 'restrictions', 'whatsoever.restrictions', 'whatsoever.', '', 'YouYou', 'maymay', 'copycopy', 'it,it,', 'givegive', 'itit', 'awayaway', 'oror', 're-usere-use', 'itit', 'underunder', 'thethe', 'terms', 'ofterms', 'of', 'thethe', 'ProjectProject', 'GutenbergGutenberg', 'LicenseLicense', 'includedincluded', 'withwith', 'thisthis', 'eBookeBook', 'oror', 'onlineonline', 'at', 'www.gutenberg.org.at', 'www.gutenberg.org.', '', 'IfIf', 'youyou', 'areare', 'notnot', 'locatedlocated', 'inin', 'thethe', 'UnitedUnited', 'States,States,', "you'll", "haveyou'll", 'have', 'toto', 'checkcheck', 'thethe', 'lawslaws', 'ofof', 'thethe', 'countrycountry', 'wherewhere', 'youyou', 'areare', 'locatedlocated', 'beforebefore', 'using', 'thisusing', 'this', 'ebook.', '', '', '', 'Title:ebook.', '', '', '', 'Title:', 'TheThe', 'Prophet', '', 'Author:Prophet', '', 'Author:', 'KahlilKahlil', 'Gibran', '', 'ReleaseGibran', '', 'Release', 'Date:Date:', 'JanuaryJanuary', '1,1,', '20192019', '[EBook[EBook', '#58585]', 'Last#58585]', 'Last', 'Updated:Updated:', 'JanuaryJanuary', '3,3,', '2018', '', '', 'Language:2018', '', '', 'Language:', 'English', '', 'CharacterEnglish', '', 'Character', 'setset', 'encoding:encoding:', 'UTF-8', '', '***UTF-8', '', '***', 'STARTSTART', 'OFOF', 'THISTHIS', 'PROJECTPROJECT', 'GUTENBERGGUTENBERG', 'EBOOKEBOOK', 'THETHE', 'PROPHETPROPHET', '***', '', '', '', '', 'Produced***', '', '', '', '', 'Produced', 'byby', 'DavidDavid', 'WidgerWidger', 'fromfrom', 'pagepage', 'imagesimages', 'generously', 'providedgenerously', 'provided', 'byby', 'thethe', 'InternetInternet', 'Archive', '', '', "Transcriber'sArchive", '', '', "Transcriber's", 'Note:Note:', 'PagePage', 'numbers,numbers,', 'ie:ie:', ',', 'areare', 'includedincluded', 'inin', 'this', 'utf-8this', 'utf-8', 'texttext', 'file.file.', 'ForFor', 'thosethose', 'wishingwishing', 'toto', 'useuse', 'aa', 'texttext', 'filefile', 'unencumbered', 'withunencumbered', 'with', 'pagepage', 'numbersnumbers', 'openopen', 'oror', 'downloaddownload', 'thethe', 'Latin-1Latin-1', 'filefile', '58585-8.txt.', '', '', '', '', '', '', '', 'THE58585-8.txt.', '', '', '', '', '', '', '', 'THE', 'PROPHET', '', 'ByPROPHET', '', 'By', 'KahlilKahlil', 'Gibran', '', 'NewGibran', '', 'New', 'York:York:', 'AlfredAlfred', 'A.A.', 'Knopf', '', '1923', '', '_TheKnopf', '', '1923', '', '_The', 'TwelveTwelve', 'IllustrationsIllustrations', 'InIn', 'ThisThis', 'Volume', 'AreVolume', 'Are', 'ReproducedReproduced', 'FromFrom', 'OriginalOriginal', 'DrawingsDrawings', 'By', 'TheBy', 'The', 'Author_', '', '', '“HisAuthor_', '', '', '“His', 'powerpower', 'camecame', 'fromfrom', 'somesome', 'greatgreat', 'reservoir', 'ofreservoir', 'of', 'spiritualspiritual', 'lifelife', 'elseelse', 'itit', 'couldcould', 'notnot', 'have', 'beenhave', 'been', 'soso', 'universaluniversal', 'andand', 'soso', 'potent,potent,', 'butbut', 'the', 'majestythe', 'majesty', 'andand', 'beautybeauty', 'ofof', 'thethe', 'languagelanguage', 'with', 'whichwith', 'which', 'hehe', 'clothedclothed', 'itit', 'werewere', 'allall', 'hishis', 'own?”', '', '--Claudeown?”', '', '--Claude', 'Bragdon', '', '', 'THEBragdon', '', '', 'THE', 'BOOKSBOOKS', 'OFOF', 'KAHLILKAHLIL', 'GIBRAN', '', 'TheGIBRAN', '', 'The', 'Madman.Madman.', '19181918', 'TwentyTwenty', 'Drawings.Drawings.', '1919', 'The1919', 'The', 'Forerunner.Forerunner.', '19201920', 'TheThe', 'Prophet.Prophet.', '1923', 'Sand1923', 'Sand', 'andand', 'Foam.Foam.', '19261926', 'JesusJesus', 'thethe', 'SonSon', 'of', 'Man.of', 'Man.' ...

# %% [markdown]
# # Challenge 2 - Filtering
#
# When printing out a few words from the book, we see that there are words that we may not want to keep if we choose to analyze the corpus of text. Below is a list of words that we would like to get rid of. Create a function that will return false if it contains a word from the list of words specified and true otherwise.

# %%
word_list = ['and', 'the', 'a', 'an']
filtrada = (list(filter(lambda x: x not in word_list,prophet_flat)))
print(filtrada)
# Out:
# ['\ufeffThe\ufeffThe', 'ProjectProject', 'GutenbergGutenberg', 'EBookEBook', 'ofof', 'TheThe', 'Prophet,Prophet,', 'byby', 'KahlilKahlil', 'Gibran', '', 'ThisGibran', '', 'This', 'eBookeBook', 'isis', 'forfor', 'thethe', 'useuse', 'ofof', 'anyoneanyone', 'anywhereanywhere', 'inin', 'thethe', 'UnitedUnited', 'StatesStates', 'mostand', 'most', 'otherother', 'partsparts', 'ofof', 'thethe', 'worldworld', 'atat', 'nono', 'costcost', 'andand', 'withwith', 'almostalmost', 'nono', 'restrictions', 'whatsoever.restrictions', 'whatsoever.', '', 'YouYou', 'maymay', 'copycopy', 'it,it,', 'givegive', 'itit', 'awayaway', 'oror', 're-usere-use', 'itit', 'underunder', 'thethe', 'terms', 'ofterms', 'of', 'thethe', 'ProjectProject', 'GutenbergGutenberg', 'LicenseLicense', 'includedincluded', 'withwith', 'thisthis', 'eBookeBook', 'oror', 'onlineonline', 'at', 'www.gutenberg.org.at', 'www.gutenberg.org.', '', 'IfIf', 'youyou', 'areare', 'notnot', 'locatedlocated', 'inin', 'thethe', 'UnitedUnited', 'States,States,', "you'll", "haveyou'll", 'have', 'toto', 'checkcheck', 'thethe', 'lawslaws', 'ofof', 'thethe', 'countrycountry', 'wherewhere', 'youyou', 'areare', 'locatedlocated', 'beforebefore', 'using', 'thisusing', 'this', 'ebook.', '', '', '', 'Title:ebook.', '', '', '', 'Title:', 'TheThe', 'Prophet', '', 'Author:Prophet', '', 'Author:', 'KahlilKahlil', 'Gibran', '', 'ReleaseGibran', '', 'Release', 'Date:Date:', 'JanuaryJanuary', '1,1,', '20192019', '[EBook[EBook', '#58585]', 'Last#58585]', 'Last', 'Updated:Updated:', 'JanuaryJanuary', '3,3,', '2018', '', '', 'Language:2018', '', '', 'Language:', 'English', '', 'CharacterEnglish', '', 'Character', 'setset', 'encoding:encoding:', 'UTF-8', '', '***UTF-8', '', '***', 'STARTSTART', 'OFOF', 'THISTHIS', 'PROJECTPROJECT', 'GUTENBERGGUTENBERG', 'EBOOKEBOOK', 'THETHE', 'PROPHETPROPHET', '***', '', '', '', '', 'Produced***', '', '', '', '', 'Produced', 'byby', 'DavidDavid', 'WidgerWidger', 'fromfrom', 'pagepage', 'imagesimages', 'generously', 'providedgenerously', 'provided', 'byby', 'thethe', 'InternetInternet', 'Archive', '', '', "Transcriber'sArchive", '', '', "Transcriber's", 'Note:Note:', 'PagePage', 'numbers,numbers,', 'ie:ie:', ',', 'areare', 'includedincluded', 'inin', 'this', 'utf-8this', 'utf-8', 'texttext', 'file.file.', 'ForFor', 'thosethose', 'wishingwishing', 'toto', 'useuse', 'aa', 'texttext', 'filefile', 'unencumbered', 'withunencumbered', 'with', 'pagepage', 'numbersnumbers', 'openopen', 'oror', 'downloaddownload', 'thethe', 'Latin-1Latin-1', 'filefile', '58585-8.txt.', '', '', '', '', '', '', '', 'THE58585-8.txt.', '', '', '', '', '', '', '', 'THE', 'PROPHET', '', 'ByPROPHET', '', 'By', 'KahlilKahlil', 'Gibran', '', 'NewGibran', '', 'New', 'York:York:', 'AlfredAlfred', 'A.A.', 'Knopf', '', '1923', '', '_TheKnopf', '', '1923', '', '_The', 'TwelveTwelve', 'IllustrationsIllustrations', 'InIn', 'ThisThis', 'Volume', 'AreVolume', 'Are', 'ReproducedReproduced', 'FromFrom', 'OriginalOriginal', 'DrawingsDrawings', 'By', 'TheBy', 'The', 'Author_', '', '', '“HisAuthor_', '', '', '“His', 'powerpower', 'camecame', 'fromfrom', 'somesome', 'greatgreat', 'reservoir', 'ofreservoir', 'of', 'spiritualspiritual', 'lifelife', 'elseelse', 'itit', 'couldcould', 'notnot', 'have', 'beenhave', 'been', 'soso', 'universaluniversal', 'andand', 'soso', 'potent,potent,', 'butbut', 'majestythe', 'majesty', 'andand', 'beautybeauty', 'ofof', 'thethe', 'languagelanguage', 'with', 'whichwith', 'which', 'hehe', 'clothedclothed', 'itit', 'werewere', 'allall', 'hishis', 'own?”', '', '--Claudeown?”', '', '--Claude', 'Bragdon', '', '', 'THEBragdon', '', '', 'THE', 'BOOKSBOOKS', 'OFOF', 'KAHLILKAHLIL', 'GIBRAN', '', 'TheGIBRAN', '', 'The', 'Madman.Madman.', '19181918', 'TwentyTwenty', 'Drawings.Drawings.', '1919', 'The1919', 'The', 'Forerunner.Forerunner.', '19201920', 'TheThe', 'Prophet.Prophet.', '1923', 'Sand1923', 'Sand', 'andand', 'Foam.Foam.', '19261926', 'JesusJesus', 'thethe', 'SonSon', 'of', 'Man.of', 'Man.', '19281928',  ...

# %% [markdown]
# Use the `filter()` function to filter out the words speficied in the `word_filter()` function. Store the filtered list in the variable `prophet_filter`.

# %% [markdown]
# # Bonus Challenge - Part 1
#
# Rewrite the `word_filter` function above to not be case sensitive.

# %%
word_list = ['and', 'the', 'a', 'an', ""]
filtrada2 = (list(filter(lambda x: x.lower() not in word_list,prophet_flat)))
print(filtrada2)
# Out:
# ['\ufeffThe\ufeffThe', 'ProjectProject', 'GutenbergGutenberg', 'EBookEBook', 'ofof', 'TheThe', 'Prophet,Prophet,', 'byby', 'KahlilKahlil', 'Gibran', 'ThisGibran', 'This', 'eBookeBook', 'isis', 'forfor', 'thethe', 'useuse', 'ofof', 'anyoneanyone', 'anywhereanywhere', 'inin', 'thethe', 'UnitedUnited', 'StatesStates', 'mostand', 'most', 'otherother', 'partsparts', 'ofof', 'thethe', 'worldworld', 'atat', 'nono', 'costcost', 'andand', 'withwith', 'almostalmost', 'nono', 'restrictions', 'whatsoever.restrictions', 'whatsoever.', 'YouYou', 'maymay', 'copycopy', 'it,it,', 'givegive', 'itit', 'awayaway', 'oror', 're-usere-use', 'itit', 'underunder', 'thethe', 'terms', 'ofterms', 'of', 'thethe', 'ProjectProject', 'GutenbergGutenberg', 'LicenseLicense', 'includedincluded', 'withwith', 'thisthis', 'eBookeBook', 'oror', 'onlineonline', 'at', 'www.gutenberg.org.at', 'www.gutenberg.org.', 'IfIf', 'youyou', 'areare', 'notnot', 'locatedlocated', 'inin', 'thethe', 'UnitedUnited', 'States,States,', "you'll", "haveyou'll", 'have', 'toto', 'checkcheck', 'thethe', 'lawslaws', 'ofof', 'thethe', 'countrycountry', 'wherewhere', 'youyou', 'areare', 'locatedlocated', 'beforebefore', 'using', 'thisusing', 'this', 'ebook.', 'Title:ebook.', 'Title:', 'TheThe', 'Prophet', 'Author:Prophet', 'Author:', 'KahlilKahlil', 'Gibran', 'ReleaseGibran', 'Release', 'Date:Date:', 'JanuaryJanuary', '1,1,', '20192019', '[EBook[EBook', '#58585]', 'Last#58585]', 'Last', 'Updated:Updated:', 'JanuaryJanuary', '3,3,', '2018', 'Language:2018', 'Language:', 'English', 'CharacterEnglish', 'Character', 'setset', 'encoding:encoding:', 'UTF-8', '***UTF-8', '***', 'STARTSTART', 'OFOF', 'THISTHIS', 'PROJECTPROJECT', 'GUTENBERGGUTENBERG', 'EBOOKEBOOK', 'THETHE', 'PROPHETPROPHET', '***', 'Produced***', 'Produced', 'byby', 'DavidDavid', 'WidgerWidger', 'fromfrom', 'pagepage', 'imagesimages', 'generously', 'providedgenerously', 'provided', 'byby', 'thethe', 'InternetInternet', 'Archive', "Transcriber'sArchive", "Transcriber's", 'Note:Note:', 'PagePage', 'numbers,numbers,', 'ie:ie:', ',', 'areare', 'includedincluded', 'inin', 'this', 'utf-8this', 'utf-8', 'texttext', 'file.file.', 'ForFor', 'thosethose', 'wishingwishing', 'toto', 'useuse', 'aa', 'texttext', 'filefile', 'unencumbered', 'withunencumbered', 'with', 'pagepage', 'numbersnumbers', 'openopen', 'oror', 'downloaddownload', 'thethe', 'Latin-1Latin-1', 'filefile', '58585-8.txt.', 'THE58585-8.txt.', 'PROPHET', 'ByPROPHET', 'By', 'KahlilKahlil', 'Gibran', 'NewGibran', 'New', 'York:York:', 'AlfredAlfred', 'A.A.', 'Knopf', '1923', '_TheKnopf', '1923', '_The', 'TwelveTwelve', 'IllustrationsIllustrations', 'InIn', 'ThisThis', 'Volume', 'AreVolume', 'Are', 'ReproducedReproduced', 'FromFrom', 'OriginalOriginal', 'DrawingsDrawings', 'By', 'TheBy', 'Author_', '“HisAuthor_', '“His', 'powerpower', 'camecame', 'fromfrom', 'somesome', 'greatgreat', 'reservoir', 'ofreservoir', 'of', 'spiritualspiritual', 'lifelife', 'elseelse', 'itit', 'couldcould', 'notnot', 'have', 'beenhave', 'been', 'soso', 'universaluniversal', 'andand', 'soso', 'potent,potent,', 'butbut', 'majestythe', 'majesty', 'andand', 'beautybeauty', 'ofof', 'thethe', 'languagelanguage', 'with', 'whichwith', 'which', 'hehe', 'clothedclothed', 'itit', 'werewere', 'allall', 'hishis', 'own?”', '--Claudeown?”', '--Claude', 'Bragdon', 'THEBragdon', 'BOOKSBOOKS', 'OFOF', 'KAHLILKAHLIL', 'GIBRAN', 'TheGIBRAN', 'Madman.Madman.', '19181918', 'TwentyTwenty', 'Drawings.Drawings.', '1919', 'The1919', 'Forerunner.Forerunner.', '19201920', 'TheThe', 'Prophet.Prophet.', '1923', 'Sand1923', 'Sand', 'andand', 'Foam.Foam.', '19261926', 'JesusJesus', 'thethe', 'SonSon', 'of', 'Man.of', 'Man.', '19281928', 'TheThe', 'ForthForth', 'Gods.Gods.', '19311931', 'Wanderer.The', 'Wanderer.', '19321932', 'TheThe', 'GardenGarden', 'ofof', 'thethe', 'Prophet', '1933Prophet', '1933', 'ProseProse', 'Poems.Poems.', '19341934', 'NymphsNymphs', 'ofof', 'Valley.the', 'Valley.', '1948', 'CONTENTS', '1948', 'CONTENTS', 'TheThe ...

# %% [markdown]
# # Challenge 3 - Reducing
#
# #### Now that we have significantly cleaned up our text corpus, let's use the `reduce()` function to put the words back together into one long string separated by spaces.
#
# We will start by writing a function that takes two strings and concatenates them together with a space between the two strings.

# %%
#lo hacemos directamente con un reduce
from functools import reduce
reducida = reduce(lambda a,e: a + " " + e ,filtrada2)
print(reducida)
# Out:
# ﻿The﻿The ProjectProject GutenbergGutenberg EBookEBook ofof TheThe Prophet,Prophet, byby KahlilKahlil Gibran ThisGibran This eBookeBook isis forfor thethe useuse ofof anyoneanyone anywhereanywhere inin thethe UnitedUnited StatesStates mostand most otherother partsparts ofof thethe worldworld atat nono costcost andand withwith almostalmost nono restrictions whatsoever.restrictions whatsoever. YouYou maymay copycopy it,it, givegive itit awayaway oror re-usere-use itit underunder thethe terms ofterms of thethe ProjectProject GutenbergGutenberg LicenseLicense includedincluded withwith thisthis eBookeBook oror onlineonline at www.gutenberg.org.at www.gutenberg.org. IfIf youyou areare notnot locatedlocated inin thethe UnitedUnited States,States, you'll haveyou'll have toto checkcheck thethe lawslaws ofof thethe countrycountry wherewhere youyou areare locatedlocated beforebefore using thisusing this ebook. Title:ebook. Title: TheThe Prophet Author:Prophet Author: KahlilKahlil Gibran ReleaseGibran Release Date:Date: JanuaryJanuary 1,1, 20192019 [EBook[EBook #58585] Last#58585] Last Updated:Updated: JanuaryJanuary 3,3, 2018 Language:2018 Language: English CharacterEnglish Character setset encoding:encoding: UTF-8 ***UTF-8 *** STARTSTART OFOF THISTHIS PROJECTPROJECT GUTENBERGGUTENBERG EBOOKEBOOK THETHE PROPHETPROPHET *** Produced*** Produced byby DavidDavid WidgerWidger fromfrom pagepage imagesimages generously providedgenerously provided byby thethe InternetInternet Archive Transcriber'sArchive Transcriber's Note:Note: PagePage numbers,numbers, ie:ie: , areare includedincluded inin this utf-8this utf-8 texttext file.file. ForFor thosethose wishingwishing toto useuse aa texttext filefile unencumbered withunencumbered with pagepage numbersnumbers openopen oror downloaddownload thethe Latin-1Latin-1 filefile 58585-8.txt. THE58585-8.txt. PROPHET ByPROPHET By KahlilKahlil Gibran NewGibran New York:York: AlfredAlfred A.A. Knopf 1923 _TheKnopf 1923 _The TwelveTwelve IllustrationsIllustrations InIn ThisThis Volume AreVolume Are ReproducedReproduced FromFrom OriginalOriginal DrawingsDrawings By TheBy Author_ “HisAuthor_ “His powerpower camecame fromfrom somesome greatgreat reservoir ofreservoir of spiritualspiritual lifelife elseelse itit couldcould notnot have beenhave been soso universaluniversal andand soso potent,potent, butbut majestythe majesty andand beautybeauty ofof thethe languagelanguage with whichwith which hehe clothedclothed itit werewere allall hishis own?” --Claudeown?” --Claude Bragdon THEBragdon BOOKSBOOKS OFOF KAHLILKAHLIL GIBRAN TheGIBRAN Madman.Madman. 19181918 TwentyTwenty Drawings.Drawings. 1919 The1919 Forerunner.Forerunner. 19201920 TheThe Prophet.Prophet. 1923 Sand1923 Sand andand Foam.Foam. 19261926 JesusJesus thethe SonSon of Man.of Man. 19281928 TheThe ForthForth Gods.Gods. 19311931 Wanderer.The Wanderer. 19321932 TheThe GardenGarden ofof thethe Prophet 1933Prophet 1933 ProseProse Poems.Poems. 19341934 NymphsNymphs ofof Valley.the Valley. 1948 CONTENTS 1948 CONTENTS TheThe ComingComing ofof thethe Ship.......7 Ship.......7 OnOn Love.....................15 Love.....................15 OnOn Marriage.................19 Marriage.................19 OnOn Children.................21 Children.................21 OnOn Giving...................23 Giving...................23 OnOn EatingEating andand Drinking......27 Drinking......27 OnOn Work.....................31 Work.....................31 OnOn JoyJoy andand Sorrow...........33 Sorrow...........33 OnOn Houses...................37 Houses...................37 OnOn Clothes..................41 Clothes..................41 OnOn BuyingBuying andand Selling.......43 Selling.......43 OnOn CrimeCrime andand Punishment.....45 Punishment.....45 OnOn Laws.....................51 Laws.....................51 OnOn Freedom..................55 Freedom..................55 OnOn ReasonReason andand Passion.......57 Passion.......57 OnOn Pain.....................60 Pain.....................60 OnOn S ...

# %% [markdown]
# Use the function above to reduce the text corpus in the list `prophet_filter` into a single string. Assign this new string to the variable `prophet_string`.

# %% [markdown]
# # Challenge 4 - Applying Functions to DataFrames
#
# #### Our next step is to use the apply function to a dataframe and transform all cells.
#
# To do this, we will load a dataset below and then write a function that will perform the transformation.

# %%
# Run this code:
# The dataset below contains information about pollution from PM2.5 particles in Beijing 

url = "https://archive.ics.uci.edu/ml/machine-learning-databases/00381/PRSA_data_2010.1.1-2014.12.31.csv"
pm25 = pd.read_csv(url)

# %% [markdown]
# Let's look at the data using the `head()` function.

# %%
# Your code here:
display(pm25.head(10))
# Out:
#    No  year  month  day  hour  pm2.5  DEWP  TEMP    PRES cbwd    Iws  Is  Ir
# 0   1  2010      1    1     0    NaN   -21 -11.0  1021.0   NW   1.79   0   0
# 1   2  2010      1    1     1    NaN   -21 -12.0  1020.0   NW   4.92   0   0
# 2   3  2010      1    1     2    NaN   -21 -11.0  1019.0   NW   6.71   0   0
# 3   4  2010      1    1     3    NaN   -21 -14.0  1019.0   NW   9.84   0   0
# 4   5  2010      1    1     4    NaN   -20 -12.0  1018.0   NW  12.97   0   0
# 5   6  2010      1    1     5    NaN   -19 -10.0  1017.0   NW  16.10   0   0
# 6   7  2010      1    1     6    NaN   -19  -9.0  1017.0   NW  19.23   0   0
# 7   8  2010      1    1     7    NaN   -19  -9.0  1017.0   NW  21.02   0   0
# 8   9  2010      1    1     8    NaN   -19  -9.0  1017.0   NW  24.15   0   0
# 9  10  2010      1    1     9    NaN   -20  -8.0  1017.0   NW  27.28   0   0

# %% [markdown]
# The next step is to create a function that divides a cell by 24 to produce an hourly figure. Write the function below.

# %%
def hourly(x):
    return x/24

# %% [markdown]
# Apply this function to the columns `Iws`, `Is`, and `Ir`. Store this new dataframe in the variable `pm25_hourly`.

# %%
# Your code here:
aplicando = pd.DataFrame(map(hourly,(pm25["Iws"], pm25["Is"], pm25["Ir"])))
aplicando = aplicando.T
display(aplicando)
# Out:
#              Iws   Is   Ir
# 0       0.074583  0.0  0.0
# 1       0.205000  0.0  0.0
# 2       0.279583  0.0  0.0
# 3       0.410000  0.0  0.0
# 4       0.540417  0.0  0.0
# ...          ...  ...  ...
# 43819   9.665417  0.0  0.0
# 43820   9.907500  0.0  0.0
# 43821  10.112500  0.0  0.0
# 43822  10.280000  0.0  0.0
# 43823  10.410417  0.0  0.0
#
# [43824 rows x 3 columns]

# %% [markdown]
# #### Our last challenge will be to create an aggregate function and apply it to a select group of columns in our dataframe.
#
# Write a function that returns the standard deviation of a column divided by the length of a column minus 1. Since we are using pandas, do not use the `len()` function. One alternative is to use `count()`. Also, use the numpy version of standard deviation.

# %%
def sample_sd(x):
    return np.std(x)/ (pm25["Iws"].count() -1)
print(sample_sd(pm25["Iws"]))
# Out:
# 0.0011411830334976838
