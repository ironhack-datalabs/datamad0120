# %% [markdown]
# ## Challenge 1: Tuples
#
# #### Do you know you can create tuples with only one element?
#
# **In the cell below, define a variable `tup` with a single element `"I"`.**
#
# *Hint: you need to add a comma (`,`) after the single element.*

# %%
# Your code here

tup = ("I")
print(tup)
# Out:
# I

# %% [markdown]
# #### Print the type of `tup`.
#
# Make sure its type is correct (i.e. *tuple* instead of *str*).

# %%
# Your code here

print(type(tup))
# Out:
# <class 'str'>

# %% [markdown]
# #### Now try to append the following elements to `tup`.
#
# Are you able to do it? Explain.
#
# ```
# "r", "o", "n", "h", "a", "c", "k',
# ```

# %%
# Your code here

elementos = ("r", "o", "n", "h", "a", "c", "k')

for e in elementos:
    tup.append(e)
print(tup)
            

# Your explanation here

No, las tuplas no son modificables.
# Out:
#   File "<ipython-input-30-414a32d02866>", line 3
#     elementos = ("r", "o", "n", "h", "a", "c", "k')
#                                                    ^
# SyntaxError: EOL while scanning string literal

# %% [markdown]
# #### How about re-assign a new value to an existing tuple?
#
# Re-assign the following elements to `tup`. Are you able to do it? Explain.
#
# ```
# "I", "r", "o", "n", "h", "a", "c", "k"
# ```

# %%
# Your code here

print(tup = "I", "r", "o", "n", "h", "a", "c", "k")
             
# Your explanation here

No se puede resaignar valores a una tupla.
# Out:
#   File "<ipython-input-25-88f2b5041f97>", line 3
#     print(tup = "I", "r", "o", "n", "h", "a", "c", "k")
#                     ^
# SyntaxError: positional argument follows keyword argument

# %% [markdown]
# #### Split `tup` into `tup1` and `tup2` with 4 elements in each.
#
# `tup1` should be `("I", "r", "o", "n")` and `tup2` should be `("h", "a", "c", "k")`.
#
# *Hint: use positive index numbers for `tup1` assignment and use negative index numbers for `tup2` assignment. Positive index numbers count from the beginning whereas negative index numbers count from the end of the sequence.*
#
# Also print `tup1` and `tup2`.

# %%
# Your code here

tup = ("I", "r", "o", "n", "h", "a", "c", "k")

tup1 = tup[:4]
tup2 = tup[4:]

print(tup1, tup2)
# Out:
# ('I', 'r', 'o', 'n') ('h', 'a', 'c', 'k')

# %% [markdown]
# #### Add `tup1` and `tup2` into `tup3` using the `+` operator.
#
# Then print `tup3` and check if `tup3` equals to `tup`.

# %%
# Your code here

tup3 = tup1 + tup2

print(tup3)
# Out:
# ('I', 'r', 'o', 'n', 'h', 'a', 'c', 'k')

# %% [markdown]
# #### Count the number of elements in `tup1` and `tup2`. Then add the two counts together and check if the sum is the same as the number of elements in `tup3`

# %%
# Your code here

print(len(tup1+tup2))
print(len(tup1+tup2)==len(tup3))
# Out:
# 8
# True

# %% [markdown]
# #### What is the index number of `"h"` in `tup3`?

# %%
# Your code here

print(tup3.index('h'))
# Out:
# 4

# %% [markdown]
# #### Now, use a FOR loop to check whether each letter in the following list is present in `tup3`:
#
# ```
# letters = ["a", "b", "c", "d", "e"]
# ```
#
# For each letter you check, print `True` if it is present in `tup3` otherwise print `False`.
#
# *Hint: you only need to loop `letters`. You don't need to loop `tup3` because there is a Python operator `in` you can use. See [reference](https://stackoverflow.com/questions/17920147/how-to-check-if-a-tuple-contains-an-element-in-python).*

# %%
# Your code here

letters = ("a", "b", "c", "d", "e")

coincidentes = 0

for e in letters:
    if e in tup3:
        coincidentes+=1

if coincidentes > 0:
    print("True")
else:
    print("False")

print(coincidentes)
# Out:
# True
# 2

# %% [markdown]
# #### How many times does each letter in `letters` appear in `tup3`?
#
# Print out the number of occurrence of each letter.

# %%
# Your code here

letras = ()

for e in letters:
    if e in tup3:
        letras.append(e)

if len(letras) == len(set(letras)):
    print(len(letras))


letters.intersection(tup3)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-95-c56f54e4c1e8> in <module>
#       5 for e in letters:
#       6     if e in tup3:
# ----> 7         letras.append(e)
#       8
#       9 if len(letras) == len(set(letras)):
#
# AttributeError: 'tuple' object has no attribute 'append'
