# %%
import os
from dotenv import load_dotenv
import json
import requests
load_dotenv()
# Out:
# True

# %%
end_forks = "/repos/ironhack-datalabs/datamad0120/forks"

# %%
def requestGithub (endpoint):
    token = os.getenv("GITHUB_APIKEY")
    if not token:
        raise ValueError ("Necesitas un token")
    direccion="https://api.github.com"
    url = direccion+endpoint
    

    print(f"Haciendo request a {url}")
    headers = {
        "Authorization": f"token {token}"}

    res = requests.get(url, headers=headers)
    return res.json()

# %%
forks = requestGithub(end_forks)
# Out:
# Haciendo request a https://api.github.com/repos/ironhack-datalabs/datamad0120/forks

# %%
print(forks)
# Out:
# [{'id': 236955988, 'node_id': 'MDEwOlJlcG9zaXRvcnkyMzY5NTU5ODg=', 'name': 'datamad0120', 'full_name': 'Nereland/datamad0120', 'private': False, 'owner': {'login': 'Nereland', 'id': 59476481, 'node_id': 'MDQ6VXNlcjU5NDc2NDgx', 'avatar_url': 'https://avatars3.githubusercontent.com/u/59476481?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/Nereland', 'html_url': 'https://github.com/Nereland', 'followers_url': 'https://api.github.com/users/Nereland/followers', 'following_url': 'https://api.github.com/users/Nereland/following{/other_user}', 'gists_url': 'https://api.github.com/users/Nereland/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/Nereland/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/Nereland/subscriptions', 'organizations_url': 'https://api.github.com/users/Nereland/orgs', 'repos_url': 'https://api.github.com/users/Nereland/repos', 'events_url': 'https://api.github.com/users/Nereland/events{/privacy}', 'received_events_url': 'https://api.github.com/users/Nereland/received_events', 'type': 'User', 'site_admin': False}, 'html_url': 'https://github.com/Nereland/datamad0120', 'description': None, 'fork': True, 'url': 'https://api.github.com/repos/Nereland/datamad0120', 'forks_url': 'https://api.github.com/repos/Nereland/datamad0120/forks', 'keys_url': 'https://api.github.com/repos/Nereland/datamad0120/keys{/key_id}', 'collaborators_url': 'https://api.github.com/repos/Nereland/datamad0120/collaborators{/collaborator}', 'teams_url': 'https://api.github.com/repos/Nereland/datamad0120/teams', 'hooks_url': 'https://api.github.com/repos/Nereland/datamad0120/hooks', 'issue_events_url': 'https://api.github.com/repos/Nereland/datamad0120/issues/events{/number}', 'events_url': 'https://api.github.com/repos/Nereland/datamad0120/events', 'assignees_url': 'https://api.github.com/repos/Nereland/datamad0120/assignees{/user}', 'branches_url': 'https://api.github.com/repos/Nereland/datamad0120/branches{/branch}', 'tags_url': 'https://api.github.com/repos/Nereland/datamad0120/tags', 'blobs_url': 'https://api.github.com/repos/Nereland/datamad0120/git/blobs{/sha}', 'git_tags_url': 'https://api.github.com/repos/Nereland/datamad0120/git/tags{/sha}', 'git_refs_url': 'https://api.github.com/repos/Nereland/datamad0120/git/refs{/sha}', 'trees_url': 'https://api.github.com/repos/Nereland/datamad0120/git/trees{/sha}', 'statuses_url': 'https://api.github.com/repos/Nereland/datamad0120/statuses/{sha}', 'languages_url': 'https://api.github.com/repos/Nereland/datamad0120/languages', 'stargazers_url': 'https://api.github.com/repos/Nereland/datamad0120/stargazers', 'contributors_url': 'https://api.github.com/repos/Nereland/datamad0120/contributors', 'subscribers_url': 'https://api.github.com/repos/Nereland/datamad0120/subscribers', 'subscription_url': 'https://api.github.com/repos/Nereland/datamad0120/subscription', 'commits_url': 'https://api.github.com/repos/Nereland/datamad0120/commits{/sha}', 'git_commits_url': 'https://api.github.com/repos/Nereland/datamad0120/git/commits{/sha}', 'comments_url': 'https://api.github.com/repos/Nereland/datamad0120/comments{/number}', 'issue_comment_url': 'https://api.github.com/repos/Nereland/datamad0120/issues/comments{/number}', 'contents_url': 'https://api.github.com/repos/Nereland/datamad0120/contents/{+path}', 'compare_url': 'https://api.github.com/repos/Nereland/datamad0120/compare/{base}...{head}', 'merges_url': 'https://api.github.com/repos/Nereland/datamad0120/merges', 'archive_url': 'https://api.github.com/repos/Nereland/datamad0120/{archive_format}{/ref}', 'downloads_url': 'https://api.github.com/repos/Nereland/datamad0120/downloads', 'issues_url': 'https://api.github.com/repos/Nereland/datamad0120/issues{/number}', 'pulls_url': 'https://api.github.com/repos/Nereland/datamad0120/pulls{/number}', 'milestones_url': 'https://api.github.com/repos/Nereland/datamad0120/milestones{/number}', 'notifications_url': 'https://api.github.com/repos/Nereland/datamad012 ...
