# %%
import os
from dotenv import load_dotenv
load_dotenv()

token = os.getenv("GITHUB_KEY")
print(f"We have a github token: {token[0:3]}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-e23f9f769d93> in <module>()
#       4
#       5 token = os.getenv("GITHUB_KEY")
# ----> 6 print(f"We have a github token: {token[0:3]}")
#
# TypeError: 'NoneType' object is not subscriptable

# %%
def requestGithub(endpoint):
    token = os.getenv("GITHUB_KEY")
    if not token:
        raise ValueError("You must set a GITHUB_KEY token")
    
    baseUrl = "https://api.github.com"
    url = baseUrl+endpoint
    print(f"Requesting data from {url}")
    headers = {
        "Authorization": f"token {token}"
    }
    res = requests.get(url,headers=headers)
    if res.status_code != 200:
        print(res.text)
        raise ValueError("Bad Response")
    return res.json()

# %%
data = requestGithub("https://github.com/ironhack-datalabs/scavenger")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-ecf86b4b8c02> in <module>()
# ----> 1 data = requestGithub("https://github.com/ironhack-datalabs/scavenger")
#
# <ipython-input-2-a0c62d600781> in requestGithub(endpoint)
#       2     token = os.getenv("GITHUB_KEY")
#       3     if not token:
# ----> 4         raise ValueError("You must set a GITHUB_KEY token")
#       5
#       6     baseUrl = "https://api.github.com"
#
# ValueError: You must set a GITHUB_KEY token
