# %%
import json
import requests
import os
from dotenv import load_dotenv

# %%
load_dotenv()

token=os.getenv("githtok")

# %%
def requestGithub(endpoint):
    token = os.getenv("githtok")
    if not token:
        raise ValueError("You must set a GITHUB_APIKEY token")
    
    baseUrl = "https://api.github.com"
    url = baseUrl+endpoint
    print(f"Requesting data from {url}")
    headers = {
        "Authorization": f"token {token}"
    }
    res = requests.get(url,headers=headers)
    if res.status_code != 200:
        print(res.text)
        raise ValueError("Bad Response")
    return res.json()

# %%
forks = requestGithub("/repos/ironhack-datalabs/datamad0120/forks")
forks
# Out:
# Requesting data from https://api.github.com/repos/ironhack-datalabs/datamad0120/forks
# [{'id': 236955988,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkyMzY5NTU5ODg=',
#   'name': 'datamad0120',
#   'full_name': 'Nereland/datamad0120',
#   'private': False,
#   'owner': {'login': 'Nereland',
#    'id': 59476481,
#    'node_id': 'MDQ6VXNlcjU5NDc2NDgx',
#    'avatar_url': 'https://avatars3.githubusercontent.com/u/59476481?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Nereland',
#    'html_url': 'https://github.com/Nereland',
#    'followers_url': 'https://api.github.com/users/Nereland/followers',
#    'following_url': 'https://api.github.com/users/Nereland/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Nereland/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Nereland/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Nereland/subscriptions',
# ...

# %%
a=[]
for fk in forks:
    b=fk["languages_url"]
    a.append(b)
a
# Out:
# ['https://api.github.com/repos/Nereland/datamad0120/languages',
#  'https://api.github.com/repos/lusuelves/datamad0120/languages',
#  'https://api.github.com/repos/Clapiniella/datamad0120/languages',
#  'https://api.github.com/repos/Teo-Lopez/datamad0120/languages',
#  'https://api.github.com/repos/Alejorro/datamad0120/languages',
#  'https://api.github.com/repos/lauravillalba/datamad0120/languages',
#  'https://api.github.com/repos/fabianlojo/datamad0120/languages',
#  'https://api.github.com/repos/vagabundoo/datamad0120-1/languages',
#  'https://api.github.com/repos/Shurlena/datamad0120/languages',
#  'https://api.github.com/repos/sowe01/datamad0120/languages',
#  'https://api.github.com/repos/Bersuan/datamad0120-1/languages',
#  'https://api.github.com/repos/SergioGomis/datamad0120/languages',
#  'https://api.github.com/repos/guille-ds/datamad0120-1/languages',
#  'https://api.github.com/repos/IvanDGregor/datamad0120/languages',
# ...

# %% [markdown]
# ### Declaro una lista vacía que almacene los lenguaje

# %%
lenguajes=[]

# %% [markdown]
# ### Declaro una función que haga una request por cada link y guarde el lenguaje si no está ya en la lista:

# %%
def requestLang(x):
    token = os.getenv("githtok")
    if not token:
        raise ValueError("You must set a GITHUB_APIKEY token")

    print(f"Requesting data from {x}")
    headers = {
        "Authorization": f"token {token}"
    }
    res = requests.get(x,headers=headers)
    if res.status_code != 200:
        print(res.text)
        raise ValueError("Bad Response")
    a = res.json().keys()
        
    for e in a:
        if e not in lenguajes:
            lenguajes.append(e)
            
    
for links in a:
    requestLang(links)
# Out:
# Requesting data from https://api.github.com/repos/Nereland/datamad0120/languages
# Requesting data from https://api.github.com/repos/lusuelves/datamad0120/languages
# Requesting data from https://api.github.com/repos/Clapiniella/datamad0120/languages
# Requesting data from https://api.github.com/repos/Teo-Lopez/datamad0120/languages
# Requesting data from https://api.github.com/repos/Alejorro/datamad0120/languages
# Requesting data from https://api.github.com/repos/lauravillalba/datamad0120/languages
# Requesting data from https://api.github.com/repos/fabianlojo/datamad0120/languages
# Requesting data from https://api.github.com/repos/vagabundoo/datamad0120-1/languages
# Requesting data from https://api.github.com/repos/Shurlena/datamad0120/languages
# Requesting data from https://api.github.com/repos/sowe01/datamad0120/languages
# Requesting data from https://api.github.com/repos/Bersuan/datamad0120-1/languages
# ...

# %% [markdown]
# ### imprimo la lista de lenguajes:

# %%
print(lenguajes)
# Out:
# ['Jupyter Notebook', 'HTML', 'Python']
