# %%
import os
from dotenv import load_dotenv
import requests
import json
import base64

load_dotenv()
# Out:
# True

# %%
token = os.getenv("GITHUB_APIKEY")

# %%
print(f"We have a github token: {token[0:3]}")
# Out:
# We have a github token: 39a

# %%
def requestGithub(endpoint):
    token = os.getenv("GITHUB_APIKEY")
    if not token:
        raise ValueError("You must set a GITHUB_APIKEY token")
    
    baseUrl = "https://api.github.com"
    url = baseUrl+endpoint
    print(f"Requesting data from {url}")
    headers = {
        "Authorization": f"token {token}"
    }
    res = requests.get(url,headers=headers)
    if res.status_code != 200:
        print(res.text)
        raise ValueError("Bad Response")
    return res.json()

# %% [markdown]
# # Challenge 1

# %%
forks = requestGithub("/repos/ironhack-datalabs/datamad0120/forks")
# Out:
# Requesting data from https://api.github.com/repos/ironhack-datalabs/datamad0120/forks

# %%
forks
# Out:
# [{'id': 236955988,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkyMzY5NTU5ODg=',
#   'name': 'datamad0120',
#   'full_name': 'Nereland/datamad0120',
#   'private': False,
#   'owner': {'login': 'Nereland',
#    'id': 59476481,
#    'node_id': 'MDQ6VXNlcjU5NDc2NDgx',
#    'avatar_url': 'https://avatars3.githubusercontent.com/u/59476481?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Nereland',
#    'html_url': 'https://github.com/Nereland',
#    'followers_url': 'https://api.github.com/users/Nereland/followers',
#    'following_url': 'https://api.github.com/users/Nereland/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Nereland/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Nereland/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Nereland/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Nereland/orgs',
#    'repos_url': 'https://api.github.com/users/Nereland/repos',
# ...

# %%
print([pr["language"] for pr in forks])
# Out:
# [None, None, None, 'Jupyter Notebook', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]

# %% [markdown]
# # Challenge 2

# %%
commits =  requestGithub("/repos/ironhack-datalabs/datamad0120/commits?since=2020-01-22")
# Out:
# Requesting data from https://api.github.com/repos/ironhack-datalabs/datamad0120/commits?since=2020-01-22

# %%
commits
# Out:
# [{'sha': '6c8dd4ca113cf9dc58d60a04a5e12441a13c08fa',
#   'node_id': 'MDY6Q29tbWl0MjMzNTc5NDU2OjZjOGRkNGNhMTEzY2Y5ZGM1OGQ2MGEwNGE1ZTEyNDQxYTEzYzA4ZmE=',
#   'commit': {'author': {'name': 'Clara',
#     'email': '55156332+Clapiniella@users.noreply.github.com',
#     'date': '2020-01-23T13:58:34Z'},
#    'committer': {'name': 'GitHub',
#     'email': 'noreply@github.com',
#     'date': '2020-01-23T13:58:34Z'},
#    'message': 'Update README.md',
#    'tree': {'sha': 'e7160f4564bfe920182fdf0072180ff8ce89130f',
#     'url': 'https://api.github.com/repos/ironhack-datalabs/datamad0120/git/trees/e7160f4564bfe920182fdf0072180ff8ce89130f'},
#    'url': 'https://api.github.com/repos/ironhack-datalabs/datamad0120/git/commits/6c8dd4ca113cf9dc58d60a04a5e12441a13c08fa',
#    'comment_count': 0,
#    'verification': {'verified': True,
#     'reason': 'valid',
# ...

# %%
print(len([pr["sha"] for pr in commits]))
# Out:
# 1

# %% [markdown]
# # Challenge 3

# %%
repo = requestGithub("/repos/ironhack-datalabs/scavenger/commits")
# Out:
# Requesting data from https://api.github.com/repos/ironhack-datalabs/scavenger/commits

# %%
repo
# Out:
# [{'sha': '9308ccc8a4c34c5e3a991ee815222a9691c32476',
#   'node_id': 'MDY6Q29tbWl0MTYyMzc1MTgxOjkzMDhjY2M4YTRjMzRjNWUzYTk5MWVlODE1MjIyYTk2OTFjMzI0NzY=',
#   'commit': {'author': {'name': 'Zhou Zhou',
#     'email': 'zhou.eye8@gmail.com',
#     'date': '2018-12-19T03:03:57Z'},
#    'committer': {'name': 'Zhou Zhou',
#     'email': 'zhou.eye8@gmail.com',
#     'date': '2018-12-19T03:03:57Z'},
#    'message': 'initial commit',
#    'tree': {'sha': '0d82bf748275dbc1239a11e9157b198d88da7383',
#     'url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/trees/0d82bf748275dbc1239a11e9157b198d88da7383'},
#    'url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/commits/9308ccc8a4c34c5e3a991ee815222a9691c32476',
#    'comment_count': 0,
#    'verification': {'verified': False,
#     'reason': 'unsigned',
#     'signature': None,
#     'payload': None}},
# ...

# %%
repo_2 = requestGithub("/repos/ironhack-datalabs/scavenger/git/trees/9308ccc8a4c34c5e3a991ee815222a9691c32476")
# Out:
# Requesting data from https://api.github.com/repos/ironhack-datalabs/scavenger/git/trees/9308ccc8a4c34c5e3a991ee815222a9691c32476

# %%
repo_2
# Out:
# {'sha': '9308ccc8a4c34c5e3a991ee815222a9691c32476',
#  'url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/trees/9308ccc8a4c34c5e3a991ee815222a9691c32476',
#  'tree': [{'path': '.gitignore',
#    'mode': '100644',
#    'type': 'blob',
#    'sha': 'e43b0f988953ae3a84b00331d0ccf5f7d51cb3cf',
#    'size': 10,
#    'url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/e43b0f988953ae3a84b00331d0ccf5f7d51cb3cf'},
#   {'path': '15024',
#    'mode': '040000',
#    'type': 'tree',
#    'sha': '2945e51c87ad5da893c954afcf092f06343bbb7d',
#    'url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/trees/2945e51c87ad5da893c954afcf092f06343bbb7d'},
#   {'path': '15534',
#    'mode': '040000',
#    'type': 'tree',
#    'sha': '5af6f2a7287e4191f39e55693fc1e9c8918d1d3a',
#    'url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/trees/5af6f2a7287e4191f39e55693fc1e9c8918d1d3a'},
#   {'path': '17020',
#    'mode': '040000',
# ...

# %%
repo_2['tree'][0]['sha']
# Out:
# 'e43b0f988953ae3a84b00331d0ccf5f7d51cb3cf'

# %%
for a in repo_2['tree']:
    print("/repos/ironhack-datalabs/scavenger/git/trees/"+a['sha'])
# Out:
# /repos/ironhack-datalabs/scavenger/git/trees/e43b0f988953ae3a84b00331d0ccf5f7d51cb3cf
# /repos/ironhack-datalabs/scavenger/git/trees/2945e51c87ad5da893c954afcf092f06343bbb7d
# /repos/ironhack-datalabs/scavenger/git/trees/5af6f2a7287e4191f39e55693fc1e9c8918d1d3a
# /repos/ironhack-datalabs/scavenger/git/trees/9c49f920aa4d9433fa99a5824128f0e6b90ec5f2
# /repos/ironhack-datalabs/scavenger/git/trees/c488d7f64088c852e22067d48fdc64ee3670f3ba
# /repos/ironhack-datalabs/scavenger/git/trees/30193d9cf62b07bcbb6366513ff03596861f2d29
# /repos/ironhack-datalabs/scavenger/git/trees/22fc3d5c2db80822c351edb2248f3491c8ebda86
# /repos/ironhack-datalabs/scavenger/git/trees/6a4a88cd9084110c8646c3cfd84dfe96b300a4a7
# /repos/ironhack-datalabs/scavenger/git/trees/c7001604cdadc2fe7b82e0f6996690718cac6941
# /repos/ironhack-datalabs/scavenger/git/trees/f84882ad7560fd2b8c6a0867bc707ce9009ef288
# /repos/ironhack-datalabs/scavenger/git/trees/46bc658c09589d9023246b00e848ce97d30d4989
# ...

# %%
requestGithub("/repos/ironhack-datalabs/scavenger/git/trees/2945e51c87ad5da893c954afcf092f06343bbb7d")
# Out:
# Requesting data from https://api.github.com/repos/ironhack-datalabs/scavenger/git/trees/2945e51c87ad5da893c954afcf092f06343bbb7d
# {'sha': '2945e51c87ad5da893c954afcf092f06343bbb7d',
#  'url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/trees/2945e51c87ad5da893c954afcf092f06343bbb7d',
#  'tree': [{'path': '.0006.scavengerhunt',
#    'mode': '100644',
#    'type': 'blob',
#    'sha': '1c9064284a24b3486015eafdb391b141c27ada2b',
#    'size': 3,
#    'url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/1c9064284a24b3486015eafdb391b141c27ada2b'},
#   {'path': '40',
#    'mode': '100644',
#    'type': 'blob',
#    'sha': 'e69de29bb2d1d6434b8b29ae775ad8c2e48c5391',
#    'size': 0,
#    'url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/e69de29bb2d1d6434b8b29ae775ad8c2e48c5391'},
#   {'path': '74',
#    'mode': '100644',
#    'type': 'blob',
#    'sha': 'e69de29bb2d1d6434b8b29ae775ad8c2e48c5391',
#    'size': 0,
# ...

# %%
repo_2 = requestGithub("/repos/ironhack-datalabs/scavenger/contents")
# Out:
# Requesting data from https://api.github.com/repos/ironhack-datalabs/scavenger/contents

# %%
repo_2[0]['name']
# Out:
# '.gitignore'

# %%
lst_dir = []
for a in repo_2:
    if a['name'] != '.gitignore':
        lst_dir.append("/repos/ironhack-datalabs/scavenger/contents/"+a['name'])

# %%
lst_dir
# Out:
# ['/repos/ironhack-datalabs/scavenger/contents/15024',
#  '/repos/ironhack-datalabs/scavenger/contents/15534',
#  '/repos/ironhack-datalabs/scavenger/contents/17020',
#  '/repos/ironhack-datalabs/scavenger/contents/30351',
#  '/repos/ironhack-datalabs/scavenger/contents/40303',
#  '/repos/ironhack-datalabs/scavenger/contents/44639',
#  '/repos/ironhack-datalabs/scavenger/contents/45525',
#  '/repos/ironhack-datalabs/scavenger/contents/47222',
#  '/repos/ironhack-datalabs/scavenger/contents/47830',
#  '/repos/ironhack-datalabs/scavenger/contents/49418',
#  '/repos/ironhack-datalabs/scavenger/contents/50896',
#  '/repos/ironhack-datalabs/scavenger/contents/55417',
#  '/repos/ironhack-datalabs/scavenger/contents/55685',
#  '/repos/ironhack-datalabs/scavenger/contents/60224',
#  '/repos/ironhack-datalabs/scavenger/contents/64880',
#  '/repos/ironhack-datalabs/scavenger/contents/66032',
#  '/repos/ironhack-datalabs/scavenger/contents/68848',
# ...

# %%
data_3 = requestGithub("/repos/ironhack-datalabs/scavenger/contents/15024")
# Out:
# Requesting data from https://api.github.com/repos/ironhack-datalabs/scavenger/contents/15024

# %%
for a in data_3:
    print(a['name'])
# Out:
# .0006.scavengerhunt
# 40
# 74
# 99

# %%
data_4 = requestGithub("/repos/ironhack-datalabs/scavenger/contents/15024/.0006.scavengerhunt")
# Out:
# Requesting data from https://api.github.com/repos/ironhack-datalabs/scavenger/contents/15024/.0006.scavengerhunt

# %%
data_4
# Out:
# {'name': '.0006.scavengerhunt',
#  'path': '15024/.0006.scavengerhunt',
#  'sha': '1c9064284a24b3486015eafdb391b141c27ada2b',
#  'size': 3,
#  'url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/contents/15024/.0006.scavengerhunt?ref=master',
#  'html_url': 'https://github.com/ironhack-datalabs/scavenger/blob/master/15024/.0006.scavengerhunt',
#  'git_url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/1c9064284a24b3486015eafdb391b141c27ada2b',
#  'download_url': 'https://raw.githubusercontent.com/ironhack-datalabs/scavenger/master/15024/.0006.scavengerhunt',
#  'type': 'file',
#  'content': 'b2YK\n',
#  'encoding': 'base64',
#  '_links': {'self': 'https://api.github.com/repos/ironhack-datalabs/scavenger/contents/15024/.0006.scavengerhunt?ref=master',
#   'git': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/1c9064284a24b3486015eafdb391b141c27ada2b',
# ...

# %%
lst_con = []
for i in lst_dir:
    lst_con.append(requestGithub(i))
# Out:
# Requesting data from https://api.github.com/repos/ironhack-datalabs/scavenger/contents/15024
# Requesting data from https://api.github.com/repos/ironhack-datalabs/scavenger/contents/15534
# Requesting data from https://api.github.com/repos/ironhack-datalabs/scavenger/contents/17020
# Requesting data from https://api.github.com/repos/ironhack-datalabs/scavenger/contents/30351
# Requesting data from https://api.github.com/repos/ironhack-datalabs/scavenger/contents/40303
# Requesting data from https://api.github.com/repos/ironhack-datalabs/scavenger/contents/44639
# Requesting data from https://api.github.com/repos/ironhack-datalabs/scavenger/contents/45525
# Requesting data from https://api.github.com/repos/ironhack-datalabs/scavenger/contents/47222
# Requesting data from https://api.github.com/repos/ironhack-datalabs/scavenger/contents/47830
# Requesting data from https://api.github.com/repos/ironhack-datalabs/scavenger/contents/49418
# ...

# %%
lst_files = []
for i in lst_con:
    for x in i:
        if '.' in x['path']:
            lst_files.append(x['path'])

# %%
lst_files
# Out:
# ['15024/.0006.scavengerhunt',
#  '15534/.0008.scavengerhunt',
#  '15534/.0012.scavengerhunt',
#  '17020/.0007.scavengerhunt',
#  '30351/.0021.scavengerhunt',
#  '40303/.0022.scavengerhunt',
#  '44639/.0005.scavengerhunt',
#  '45525/.0018.scavengerhunt',
#  '47222/.0016.scavengerhunt',
#  '47222/.0024.scavengerhunt',
#  '47830/.0010.scavengerhunt',
#  '49418/.0014.scavengerhunt',
#  '50896/.0011.scavengerhunt',
#  '55417/.0023.scavengerhunt',
#  '55685/.0020.scavengerhunt',
#  '60224/.0003.scavengerhunt',
#  '68848/.0004.scavengerhunt',
#  '70751/.0019.scavengerhunt',
#  '70985/.0017.scavengerhunt',
#  '88596/.0002.scavengerhunt',
#  '89338/.0013.scavengerhunt',
#  '91701/.0015.scavengerhunt',
#  '97881/.0009.scavengerhunt',
#  '98750/.0001.scavengerhunt']

# %%
files_sorted = sorted(lst_files, key=lambda x: (x[9], x[10]))

# %%
files_sorted
# Out:
# ['98750/.0001.scavengerhunt',
#  '88596/.0002.scavengerhunt',
#  '60224/.0003.scavengerhunt',
#  '68848/.0004.scavengerhunt',
#  '44639/.0005.scavengerhunt',
#  '15024/.0006.scavengerhunt',
#  '17020/.0007.scavengerhunt',
#  '15534/.0008.scavengerhunt',
#  '97881/.0009.scavengerhunt',
#  '47830/.0010.scavengerhunt',
#  '50896/.0011.scavengerhunt',
#  '15534/.0012.scavengerhunt',
#  '89338/.0013.scavengerhunt',
#  '49418/.0014.scavengerhunt',
#  '91701/.0015.scavengerhunt',
#  '47222/.0016.scavengerhunt',
#  '70985/.0017.scavengerhunt',
#  '45525/.0018.scavengerhunt',
#  '70751/.0019.scavengerhunt',
#  '55685/.0020.scavengerhunt',
#  '30351/.0021.scavengerhunt',
#  '40303/.0022.scavengerhunt',
#  '55417/.0023.scavengerhunt',
#  '47222/.0024.scavengerhunt']

# %%
lst_words = []
for i in files_sorted:
    lst_words.append(requestGithub("/repos/ironhack-datalabs/scavenger/contents/"+i))
# Out:
# Requesting data from https://api.github.com/repos/ironhack-datalabs/scavenger/contents/98750/.0001.scavengerhunt
# Requesting data from https://api.github.com/repos/ironhack-datalabs/scavenger/contents/88596/.0002.scavengerhunt
# Requesting data from https://api.github.com/repos/ironhack-datalabs/scavenger/contents/60224/.0003.scavengerhunt
# Requesting data from https://api.github.com/repos/ironhack-datalabs/scavenger/contents/68848/.0004.scavengerhunt
# Requesting data from https://api.github.com/repos/ironhack-datalabs/scavenger/contents/44639/.0005.scavengerhunt
# Requesting data from https://api.github.com/repos/ironhack-datalabs/scavenger/contents/15024/.0006.scavengerhunt
# Requesting data from https://api.github.com/repos/ironhack-datalabs/scavenger/contents/17020/.0007.scavengerhunt
# Requesting data from https://api.github.com/repos/ironhack-datalabs/scavenger/contents/15534/.0008.scavengerhunt
# ...

# %%
lst_frase = ''
for i in lst_words:
    a = base64.b64decode(i['content'])
    b = a.decode("UTF-8").replace('\n', ' ')
    lst_frase += b

# %%
lst_frase.strip()
# Out:
# 'In data science, 80 percent of time spent is preparing data, 20 percent of time is spent complaining about the need to prepare data.'
