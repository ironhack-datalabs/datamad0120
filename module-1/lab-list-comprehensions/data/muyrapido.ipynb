# %%
import pandas as pd
df = pd.read_csv('./geoesp.csv')

# %%
df
# Out:
#      Unnamed: 0                       _id        lat        lng  \
# 0             0  5d231e0ae0aeedf6e06cd897  40.738567 -73.987199
# 1             1  5d231e0ae0aeedf6e06cbdd7  40.739341 -73.988357
# 2             2  5d231e0ae0aeedf6e06cb8aa  40.737721 -73.987725
# 3             3  5d231e0ae0aeedf6e06ce298  40.740154 -73.986742
# 4             4  5d231e0ae0aeedf6e06ccbbd  40.740207 -73.987002
# ..          ...                       ...        ...        ...
# 521         521  5d231e0ae0aeedf6e06cdbb7  40.779959 -73.976151
# 522         522  5d231e0ae0aeedf6e06cbb08  40.771778 -73.951350
# 523         523  5d231e0ae0aeedf6e06cb243  40.781159 -73.978332
# 524         524  5d231e0ae0aeedf6e06cbb39  40.716144 -74.035070
# 525         525  5d231e0ae0aeedf6e06cb391  40.694731 -73.983268
#
#                   name                                  oficina_principal  \
# 0            SpaBooker  {'type': 'Point', 'coordinates': [-73.987199, ...
# ...

# %%
df = df[["lat","lng","name","totalOffices"]]

# %%
df.lat = df.lat.astype('float32')
df.lng = df.lng.astype('float32')

# %%
df.to_json("cleaned.json",orient="records")
